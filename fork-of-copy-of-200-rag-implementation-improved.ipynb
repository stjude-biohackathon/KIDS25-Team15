# %%
import os

# %%
# !pip install --quiet --upgrade datasets langchain langchain-community langchain-chroma sentence-transformers umap-learn matplotlib scikit-learn
# !pip install --upgrade PyMuPDF
# !pip install huggingface_hub
# !pip install pandas requests beautifulsoup4 PyMuPDF datasets \
    langchain langchain-community langchain-chroma sentence-transformers \
    scikit-learn matplotlib torch
# Out:
# Requirement already satisfied: PyMuPDF in /usr/local/lib/python3.11/dist-packages (1.26.4)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.11/dist-packages (0.33.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (2025.5.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (2.32.5)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (4.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (1.1.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub) (2025.6.15)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.5)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (4.13.4)
# Requirement already satisfied: PyMuPDF in /usr/local/lib/python3.11/dist-packages (1.26.4)
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (4.1.1)
# Requirement already satisfied: langchain in /usr/local/lib/python3.11/dist-packages (0.3.27)
# Requirement already satisfied: langchain-community in /usr/local/lib/python3.11/dist-packages (0.3.30)
# Requirement already satisfied: langchain-chroma in /usr/local/lib/python3.11/dist-packages (0.2.6)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.11/dist-packages (5.1.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.7.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.6)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.6.15)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (4.14.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.18.0)
# Requirement already satisfied: pyarrow>=21.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (21.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.9.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (2025.5.1)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.33.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.72 in /usr/local/lib/python3.11/dist-packages (from langchain) (0.3.76)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in /usr/local/lib/python3.11/dist-packages (from langchain) (0.3.11)
# Requirement already satisfied: langsmith>=0.1.17 in /usr/local/lib/python3.11/dist-packages (from langchain) (0.4.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.11/dist-packages (from langchain) (2.11.7)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.11/dist-packages (from langchain) (2.0.41)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (3.12.13)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (8.5.0)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (2.11.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (0.4.1)
# Requirement already satisfied: chromadb>=1.0.20 in /usr/local/lib/python3.11/dist-packages (from langchain-chroma) (1.1.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.52.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.15.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (11.2.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.20.1)
# Requirement already satisfied: build>=1.0.3 in /usr/local/lib/python3.11/dist-packages (from chromadb>=1.0.20->langchain-chroma) (1.2.2.post1)
# Requirement already satisfied: pybase64>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from chromadb>=1.0.20->langchain-chroma) (1.4.2)
# Requirement already satisfied: uvicorn>=0.18.3 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.18.3->chromadb>=1.0.20->langchain-chroma) (0.34.3)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=1.0.20->langchain-chroma) (5.4.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /usr/local/lib/python3.11/dist-packages (from chromadb>=1.0.20->langchain-chroma) (1.23.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=1.0.20->langchain-chroma) (1.37.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=1.0.20->langchain-chroma) (1.37.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=1.0.20->langchain-chroma) (1.37.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/lib/python3.11/dist-packages (from chromadb>=1.0.20->langchain-chroma) (0.21.2)
# Requirement already satisfied: pypika>=0.48.9 in /usr/local/lib/python3.11/dist-packages (from chromadb>=1.0.20->langchain-chroma) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in /usr/local/lib/python3.11/dist-packages (from chromadb>=1.0.20->langchain-chroma) (7.7.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.11/dist-packages (from chromadb>=1.0.20->langchain-chroma) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=1.0.20->langchain-chroma) (1.73.1)
# Requirement already satisfied: bcrypt>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from chromadb>=1.0.20->langchain-chroma) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=1.0.20->langchain-chroma) (0.16.0)
# Requirement already satisfied: kubernetes>=28.1.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=1.0.20->langchain-chroma) (33.1.0)
# Requirement already satisfied: mmh3>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from chromadb>=1.0.20->langchain-chroma) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in /usr/local/lib/python3.11/dist-packages (from chromadb>=1.0.20->langchain-chroma) (3.10.18)
# Requirement already satisfied: httpx>=0.27.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=1.0.20->langchain-chroma) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=1.0.20->langchain-chroma) (14.0.0)
# Requirement already satisfied: jsonschema>=4.19.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=1.0.20->langchain-chroma) (4.24.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24.0->datasets) (1.1.5)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (1.33)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.2->pandas) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.2->pandas) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.2->pandas) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.2->pandas) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.2->pandas) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.2->pandas) (2.4.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.1.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: pyproject_hooks in /usr/local/lib/python3.11/dist-packages (from build>=1.0.3->chromadb>=1.0.20->langchain-chroma) (1.2.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx>=0.27.0->chromadb>=1.0.20->langchain-chroma) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.27.0->chromadb>=1.0.20->langchain-chroma) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.27.0->chromadb>=1.0.20->langchain-chroma) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.72->langchain) (3.0.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=4.19.0->chromadb>=1.0.20->langchain-chroma) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=4.19.0->chromadb>=1.0.20->langchain-chroma) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=4.19.0->chromadb>=1.0.20->langchain-chroma) (0.25.1)
# Requirement already satisfied: google-auth>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb>=1.0.20->langchain-chroma) (2.40.3)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb>=1.0.20->langchain-chroma) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb>=1.0.20->langchain-chroma) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb>=1.0.20->langchain-chroma) (3.3.1)
# Requirement already satisfied: durationpy>=0.7 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb>=1.0.20->langchain-chroma) (0.10)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.14.1->chromadb>=1.0.20->langchain-chroma) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.14.1->chromadb>=1.0.20->langchain-chroma) (25.2.10)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.14.1->chromadb>=1.0.20->langchain-chroma) (6.32.1)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-api>=1.2.0->chromadb>=1.0.20->langchain-chroma) (8.7.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=1.0.20->langchain-chroma) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.37.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=1.0.20->langchain-chroma) (1.37.0)
# Requirement already satisfied: opentelemetry-proto==1.37.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=1.0.20->langchain-chroma) (1.37.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-sdk>=1.2.0->chromadb>=1.0.20->langchain-chroma) (0.58b0)
# Requirement already satisfied: backoff>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from posthog<6.0.0,>=2.4.0->chromadb>=1.0.20->langchain-chroma) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from posthog<6.0.0,>=2.4.0->chromadb>=1.0.20->langchain-chroma) (1.9.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->chromadb>=1.0.20->langchain-chroma) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->chromadb>=1.0.20->langchain-chroma) (2.19.2)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer>=0.9.0->chromadb>=1.0.20->langchain-chroma) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer>=0.9.0->chromadb>=1.0.20->langchain-chroma) (1.5.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: httptools>=0.6.3 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.18.3->chromadb>=1.0.20->langchain-chroma) (0.6.4)
# Requirement already satisfied: uvloop>=0.15.1 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.18.3->chromadb>=1.0.20->langchain-chroma) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.18.3->chromadb>=1.0.20->langchain-chroma) (1.1.0)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.18.3->chromadb>=1.0.20->langchain-chroma) (15.0.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.23.2->pandas) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.23.2->pandas) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.23.2->pandas) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.23.2->pandas) (2024.2.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=1.0.20->langchain-chroma) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=1.0.20->langchain-chroma) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=1.0.20->langchain-chroma) (4.9.1)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb>=1.0.20->langchain-chroma) (3.23.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.23.2->pandas) (2024.2.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb>=1.0.20->langchain-chroma) (0.1.2)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx>=0.27.0->chromadb>=1.0.20->langchain-chroma) (1.3.1)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.11/dist-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb>=1.0.20->langchain-chroma) (10.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=1.0.20->langchain-chroma) (0.6.1)

# %%
# import sys
# print(sys.executable)

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import fitz  # PyMuPDF
from datasets import load_dataset
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_chroma import Chroma
from langchain_community.embeddings import HuggingFaceEmbeddings

from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import torch
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ## Load Data

# %%
df_disease = pd.read_csv("/kaggle/input/scraped-output-metadata-new-csv/scraped_output_metadata_new.csv")
df_family = pd.read_csv("/kaggle/input/scraped-output/scraped_output_famresource_metadata.csv")
df_housing = pd.read_csv("/kaggle/input/scraped-output/scraped_output_housing_metadata_new.csv")
df_meal = pd.read_csv("/kaggle/input/scraped-output/scraped_output_meal_metadata_new.csv")
df_alldisease = pd.read_csv("/kaggle/input/scraped-output-alldisease-other/scraped_output_alldisease_metadata_new.csv")
df_other = pd.read_csv("/kaggle/input/scraped-output-alldisease-other/scraped_output_otherrelevant_metadata_new.csv")

# %%
df = pd.concat([df_disease, df_family, df_housing, df_meal, df_alldisease, df_other], axis = 0)

# %%
pd.set_option("display.max_colwidth", 1000)
# df = pd.read_csv("/kaggle/input/scraped-output-metadata-new-csv/scraped_output_metadata_new.csv")

# %%
import os
os.getcwd()
# Out:
# '/kaggle/working'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5779 entries, 0 to 3563
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  5779 non-null   int64
#  1   text        5778 non-null   object
#  2   metadata    5779 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 180.6+ KB

# %%
# df = df.rename(columns= {'scraped_Content': 'scraped_content'})

# %%
# df_filtered = df.drop(index = [4, 5, 14, 15, 24, 25])

# %%
# df_filtered_reset_index = df_filtered.reset_index()
# df_filtered_reset_index = df_filtered_reset_index.drop(columns = 'index')
# df_filtered_reset_index.info()

# %%
# df_filtered_reset_index.sample(2)

# %%
#import pandas as pd

# Load the uploaded CSV
#file_path = "/content/scraped_output_metadata.csv"
#df = pd.read_csv(file_path)

# Remove duplicate rows based on the "text" column (keeping the first occurrence)
#df_cleaned = df.drop_duplicates(subset=["text"], keep="first").reset_index(drop=True)

# Shift the numbering if there's an index-like column (e.g., auto increment)
# For demonstration, create a new sequential index column starting from 0
#df_cleaned.insert(0, "new_index", range(len(df_cleaned)))

# Save cleaned file
#output_path = "/content/scraped_output_metadata_cleaned.csv"
#df_cleaned.to_csv(output_path, index=False)

#output_path
# Out:
# '/content/scraped_output_metadata_cleaned.csv'

# %%
#df = df_cleaned

# %%
pd.set_option("display.max_colwidth", 500)

# %%
df.head()
# Out:
#    Unnamed: 0  \
# 0           0
# 1           1
# 2           2
# 3           3
# 4           4
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   text  \
# 0  Your child’s treatment for cancer depends on the type of cancer they have and how advanced it is. Treatments may include chemotherapy, radiation therapy, surgery, targeted therapy, immunotherapy, and stem cell (bone marrow) transplant. Find trusted resources you can understand to help you as you make decisions.\nAllogeneic Stem Cell (Bone Marrow) Transplant\nAutologous Stem Cell (Bone Marrow) Transplant\nBrachytherapy\nCAR T-Cell Therapy\nChemotherapy\nImmunotherapy\nProton Beam Radiation\nR...
# 1  TreatmentsTreatments for childhood illnesses include medicine, surgery, radiation, stem cell transplant, immunotherapy, or targeted therapy. Learn about these treatments.\nTreatments for childhood illnesses include medicine, surgery, radiation, stem cell transplant, immunotherapy, or targeted therapy. Learn about these treatments.\nHow Treatments May Affect YouKnowing the facts about treatment and side effects can help you be informed about your care. Get the facts about how treatment works ...
# 2                                                                                                                                                                                                                                                                                                                                                                                            A new radiation treatment may treat brain tumors with fewer side effects so patients can function better after treatment.
# 3  Managing symptoms and side effects is important to your child’s recovery and well-being. Learn more about cancer symptoms and treatment side effects.\nANC and Neutropenia\nAnemia\nAvascular Necrosis (Osteonecrosis)\nBlood Clots\nCentral Venous Line (Catheter) Complications\nChemo Brain\nConstipation\nCytokine Release Syndrome\nDehydration\nDelayed Wound Healing\nDelirium\nDiarrhea\nDysarthria\nExcessive Daytime Sleepiness, Hypersomnia, and Narcolepsy\nFatigue\nFever and Signs of Infection\nG...
# 4  Coping with Side EffectsSide effects are unintended effects or unwanted symptoms that occur because of medicines or other treatments. Learn how to manage and cope with side effects.\nSide effects are unintended effects or unwanted symptoms that occur because of medicines or other treatments. Learn how to manage and cope with side effects.\nPain ManagementPain management is an important part of care for children with cancer or other illnesses. Learn ways to prevent and manage pain.\nPain mana...
#
#                                                                                                                                                                                                                                                                                                                        metadata
# 0                          {'source_url': 'https://together.stjude.org/en-us/conditions/cancers/cancer-treatments.html', 'retrieved_at': '2025-09-29T18:09:04.907923', 'title': 'Cancer Treatments   - Together by St. Jude™', 'section': 'Learn about treatments for childhood and adolescent cancers', 'super_section': None}
# 1                                                                   {'source_url': 'https://together.stjude.org/en-us/conditions/cancers/cancer-treatments.html', 'retrieved_at': '2025-09-29T18:09:04.907923', 'title': 'Cancer Treatments   - Together by St. Jude™', 'section': 'Featured resources', 'super_section': None}
# 2                                                                   {'source_url': 'https://together.stjude.org/en-us/conditions/cancers/cancer-treatments.html', 'retrieved_at': '2025-09-29T18:09:04.907923', 'title': 'Cancer Treatments   - Together by St. Jude™', 'section': 'Research Spotlight', 'super_section': None}
# 3  {'source_url': 'https://together.stjude.org/en-us/conditions/cancers/cancer-symptoms-side-effects.html', 'retrieved_at': '2025-09-29T18:09:05.128189', 'title': 'Cancer Symptoms and Side Effects - Together by St. Jude™', 'section': 'Learn about managing your child’s symptoms and side effects', 'super_section': None}
# 4                                           {'source_url': 'https://together.stjude.org/en-us/conditions/cancers/cancer-symptoms-side-effects.html', 'retrieved_at': '2025-09-29T18:09:05.128189', 'title': 'Cancer Symptoms and Side Effects - Together by St. Jude™', 'section': 'Featured resources', 'super_section': None}

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1116 entries, 0 to 1115
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1116 non-null   int64
#  1   text        1116 non-null   object
#  2   metadata    1116 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 26.3+ KB

# %%
import ast

df['metadata'] = df['metadata'].apply(
    lambda x: ast.literal_eval(x) if isinstance(x, str) else x
)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1551 entries, 0 to 77
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1551 non-null   int64
#  1   text        1550 non-null   object
#  2   metadata    1551 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 48.5+ KB

# %%
df = df.iloc[:, 1:]

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5778 entries, 0 to 3563
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  5778 non-null   int64
#  1   text        5778 non-null   object
#  2   metadata    5778 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 180.6+ KB

# %% [markdown]
# ## Document Indexing

# %% [markdown]
# ### Chunking

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
from typing import Iterable, List

def chunk_text(
    text: str,
    chunk_size: int = 800,
    chunk_overlap: int = 80
) -> List[str]:
    splitter = RecursiveCharacterTextSplitter(
        chunk_size=chunk_size,
        chunk_overlap=chunk_overlap,
        separators=["\n\n", "\n", ".", " "]
    )
    return splitter.split_text(text)

def build_chunks_dataframe(
    df: pd.DataFrame,
    chunk_size: int = 800,
    chunk_overlap: int = 80
) -> pd.DataFrame:

    records = []

    for source_idx, row in df.iterrows():
        seg_text = row['text']
        seg_metadata = row['metadata']

        seg_chunks = chunk_text(seg_text, chunk_size, chunk_overlap)

        for chunk_idx, chunk in enumerate(seg_chunks):
            meta = seg_metadata.copy()
            meta['source_idx'] = source_idx
            meta['chunk_idx'] = chunk_idx

            records.append({'chunk_text': chunk,
                            'metadata': meta})

    return pd.DataFrame(records)

# %%
df_chunks = build_chunks_dataframe(df)

# %%
df_chunks
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  chunk_text  \
# 0                                                                                                                                                                                                                                Your child’s treatment for cancer depends on the type of cancer they have and how advanced it is. Treatments may include chemotherapy, radiation therapy, surgery, targeted therapy, immunotherapy, and stem cell (bone marrow) transplant. Find trusted resources you can understand to help you as you make decisions.\nAllogeneic Stem Cell (Bone Marrow) Transplant\nAutologous Stem Cell (Bone Marrow) Transplant\nBrachytherapy\nCAR T-Cell Therapy\nChemotherapy\nImmunotherapy\nProton Beam Radiation\nRadiation Therapy\nStem Cell Transplant\nSurface Guided Radiation Therapy (SGRT)\nSurgery\nTargeted Therapy
# 1                                                                                                   TreatmentsTreatments for childhood illnesses include medicine, surgery, radiation, stem cell transplant, immunotherapy, or targeted therapy. Learn about these treatments.\nTreatments for childhood illnesses include medicine, surgery, radiation, stem cell transplant, immunotherapy, or targeted therapy. Learn about these treatments.\nHow Treatments May Affect YouKnowing the facts about treatment and side effects can help you be informed about your care. Get the facts about how treatment works and how it may affect you now and later in life.\nKnowing the facts about treatment and side effects can help you be informed about your care. Get the facts about how treatment works and how it may affect you now and later in life.
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                         Video LibraryListen to hopeful thoughts, medical explanations, and practical advice from families and care teams facing childhood and adolescent cancer, blood disorders, and other serious illnesses.\nListen to hopeful thoughts, medical explanations, and practical advice from families and care teams facing childhood and adolescent cancer, blood disorders, and other serious illnesses.
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 A new radiation treatment may treat brain tumors with fewer side effects so patients can function better after treatment.
# 4     Managing symptoms and side effects is important to your child’s recovery and well-being. Learn more about cancer symptoms and treatment side effects.\nANC and Neutropenia\nAnemia\nAvascular Necrosis (Osteonecrosis)\nBlood Clots\nCentral Venous Line (Catheter) Complications\nChemo Brain\nConstipation\nCytokine Release Syndrome\nDehydration\nDelayed Wound Healing\nDelirium\nDiarrhea\nDysarthria\nExcessive Daytime Sleepiness, Hypersomnia, and Narcolepsy\nFatigue\nFever and Signs of Infection\nGraft Versus Host Disease\nHair Loss\nHearing Loss\nInfertility in Male Cancer and Stem Cell Transplant Patients\nInsomnia\nJaundice\nLoss of Appetite and Weight Loss\nMalignant Hyperthermia\nMouth and Throat Sores\nNausea and Vomiting During Cancer Treatment\nNeuropathic Pain\nPeripheral Neuropathy\nPosterior Fossa Syndrome
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ...
# 6341                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Please arrive on time. If you are late, it might be hard to complete the testing and the evaluation might not happen.\nIf you need to cancel your appointment, call as soon as possible to reschedule.
# 6342                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  A psychology team member will contact you. They will tell you the results and suggest things that can help your child.\nYou can speak with your care team about how to get your child’s report. The report might have a plan of things you can do to help your child.
# 6343                                                                                                                                                                                                                                                                                                                                                                                                                                                     You can use this information to:\nHelp your child do difficult things in an easier way.\nShare the results with your child's teachers and health care team. The results help them care for your child.\nShare the results with organizations that can help your child. Examples would be the state Vocational Rehabilitation office or the Office of Student Disabilities at your child's college.
# 6344                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Psychological and neuropsychological evaluations tell you about your child's thinking, learning, emotions, and behavior.\nThese evaluations can help you know more about your child's strengths and weaknesses.\nYour child’s care team will use results to develop a plan to support your child or make referrals to other services.
# 6345                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Psychology and Mental Health Services\nMental Health\n—Reviewed: July 2022
#
#                                                                                                                                                                                                                                                                                                                                                            metadata
# 0                             {'source_url': 'https://together.stjude.org/en-us/conditions/cancers/cancer-treatments.html', 'retrieved_at': '2025-09-29T18:09:04.907923', 'title': 'Cancer Treatments   - Together by St. Jude™', 'section': 'Learn about treatments for childhood and adolescent cancers', 'super_section': None, 'source_idx': 0, 'chunk_idx': 0}
# 1                                                                      {'source_url': 'https://together.stjude.org/en-us/conditions/cancers/cancer-treatments.html', 'retrieved_at': '2025-09-29T18:09:04.907923', 'title': 'Cancer Treatments   - Together by St. Jude™', 'section': 'Featured resources', 'super_section': None, 'source_idx': 1, 'chunk_idx': 0}
# 2                                                                      {'source_url': 'https://together.stjude.org/en-us/conditions/cancers/cancer-treatments.html', 'retrieved_at': '2025-09-29T18:09:04.907923', 'title': 'Cancer Treatments   - Together by St. Jude™', 'section': 'Featured resources', 'super_section': None, 'source_idx': 1, 'chunk_idx': 1}
# 3                                                                      {'source_url': 'https://together.stjude.org/en-us/conditions/cancers/cancer-treatments.html', 'retrieved_at': '2025-09-29T18:09:04.907923', 'title': 'Cancer Treatments   - Together by St. Jude™', 'section': 'Research Spotlight', 'super_section': None, 'source_idx': 2, 'chunk_idx': 0}
# 4     {'source_url': 'https://together.stjude.org/en-us/conditions/cancers/cancer-symptoms-side-effects.html', 'retrieved_at': '2025-09-29T18:09:05.128189', 'title': 'Cancer Symptoms and Side Effects - Together by St. Jude™', 'section': 'Learn about managing your child’s symptoms and side effects', 'super_section': None, 'source_idx': 3, 'chunk_idx': 0}
# ...                                                                                                                                                                                                                                                                                                                                                             ...
# 6341                  {'source_url': 'https://together.stjude.org/en-us/medical-care/psychology/psychology-evaluation.html', 'retrieved_at': '2025-09-29T20:51:29.934095', 'title': 'Psychological and Neuropsychological Evaluations  - Together by St. Jude™', 'section': 'Your appointment schedule', 'super_section': None, 'source_idx': 3559, 'chunk_idx': 0}
# 6342                     {'source_url': 'https://together.stjude.org/en-us/medical-care/psychology/psychology-evaluation.html', 'retrieved_at': '2025-09-29T20:51:29.934095', 'title': 'Psychological and Neuropsychological Evaluations  - Together by St. Jude™', 'section': 'Receiving test results', 'super_section': None, 'source_idx': 3560, 'chunk_idx': 0}
# 6343          {'source_url': 'https://together.stjude.org/en-us/medical-care/psychology/psychology-evaluation.html', 'retrieved_at': '2025-09-29T20:51:29.934095', 'title': 'Psychological and Neuropsychological Evaluations  - Together by St. Jude™', 'section': 'How to use the evaluation results', 'super_section': None, 'source_idx': 3561, 'chunk_idx': 0}
# 6344                                 {'source_url': 'https://together.stjude.org/en-us/medical-care/psychology/psychology-evaluation.html', 'retrieved_at': '2025-09-29T20:51:29.934095', 'title': 'Psychological and Neuropsychological Evaluations  - Together by St. Jude™', 'section': 'Key Points', 'super_section': None, 'source_idx': 3562, 'chunk_idx': 0}
# 6345                       {'source_url': 'https://together.stjude.org/en-us/medical-care/psychology/psychology-evaluation.html', 'retrieved_at': '2025-09-29T20:51:29.934095', 'title': 'Psychological and Neuropsychological Evaluations  - Together by St. Jude™', 'section': 'For more information', 'super_section': None, 'source_idx': 3563, 'chunk_idx': 0}
#
# [6346 rows x 2 columns]

# %%
# df['chunk_text'] = df['scraped_content'].apply(lambda x: chunk_text(x, chunk_size = 800, chunk_overlap = 80))

# %%
# df_chunks['chunk_count'] = df_chunks['chunk_text'].apply(len)

# %%
# from itertools import chain

# all_chunks = list(chain.from_iterable(df_chunks['chunk_text']))

# total_chunks = len(all_chunks)
# total_doc = len(df_chunks)
# print(f"Total Chunk Texts: {total_chunks}")
# print(f"Average Chunk per Document: {(total_chunks / total_doc):.2f}")

# %%
all_chunks = df_chunks['chunk_text'].tolist()
all_metas = df_chunks['metadata'].tolist()

# %%
len(all_chunks)
# Out:
# 6346

# %%
all_chunks[:5]
# Out:
# ['Your child’s treatment for cancer depends on the type of cancer they have and how advanced it is. Treatments may include chemotherapy, radiation therapy, surgery, targeted therapy, immunotherapy, and stem cell (bone marrow) transplant. Find trusted resources you can understand to help you as you make decisions.\nAllogeneic Stem Cell (Bone Marrow) Transplant\nAutologous Stem Cell (Bone Marrow) Transplant\nBrachytherapy\nCAR T-Cell Therapy\nChemotherapy\nImmunotherapy\nProton Beam Radiation\nRadiation Therapy\nStem Cell Transplant\nSurface Guided Radiation Therapy (SGRT)\nSurgery\nTargeted Therapy',
#  'TreatmentsTreatments for childhood illnesses include medicine, surgery, radiation, stem cell transplant, immunotherapy, or targeted therapy. Learn about these treatments.\nTreatments for childhood illnesses include medicine, surgery, radiation, stem cell transplant, immunotherapy, or targeted therapy. Learn about these treatments.\nHow Treatments May Affect YouKnowing the facts about treatment and side effects can help you be informed about your care. Get the facts about how treatment works and how it may affect you now and later in life.\nKnowing the facts about treatment and side effects can help you be informed about your care. Get the facts about how treatment works and how it may affect you now and later in life.',
#  'Video LibraryListen to hopeful thoughts, medical explanations, and practical advice from families and care teams facing childhood and adolescent cancer, blood disorders, and other serious illnesses.\nListen to hopeful thoughts, medical explanations, and practical advice from families and care teams facing childhood and adolescent cancer, blood disorders, and other serious illnesses.',
#  'A new radiation treatment may treat brain tumors with fewer side effects so patients can function better after treatment.',
#  'Managing symptoms and side effects is important to your child’s recovery and well-being. Learn more about cancer symptoms and treatment side effects.\nANC and Neutropenia\nAnemia\nAvascular Necrosis (Osteonecrosis)\nBlood Clots\nCentral Venous Line (Catheter) Complications\nChemo Brain\nConstipation\nCytokine Release Syndrome\nDehydration\nDelayed Wound Healing\nDelirium\nDiarrhea\nDysarthria\nExcessive Daytime Sleepiness, Hypersomnia, and Narcolepsy\nFatigue\nFever and Signs of Infection\nGraft Versus Host Disease\nHair Loss\nHearing Loss\nInfertility in Male Cancer and Stem Cell Transplant Patients\nInsomnia\nJaundice\nLoss of Appetite and Weight Loss\nMalignant Hyperthermia\nMouth and Throat Sores\nNausea and Vomiting During Cancer Treatment\nNeuropathic Pain\nPeripheral Neuropathy\nPosterior Fossa Syndrome']

# %%
all_metas[:5]
# Out:
# [{'source_url': 'https://together.stjude.org/en-us/conditions/cancers/cancer-treatments.html',
#   'retrieved_at': '2025-09-29T18:09:04.907923',
#   'title': 'Cancer Treatments   - Together by St. Jude™',
#   'section': 'Learn about treatments for childhood and adolescent cancers',
#   'super_section': None,
#   'source_idx': 0,
#   'chunk_idx': 0},
#  {'source_url': 'https://together.stjude.org/en-us/conditions/cancers/cancer-treatments.html',
#   'retrieved_at': '2025-09-29T18:09:04.907923',
#   'title': 'Cancer Treatments   - Together by St. Jude™',
#   'section': 'Featured resources',
#   'super_section': None,
#   'source_idx': 1,
#   'chunk_idx': 0},
#  {'source_url': 'https://together.stjude.org/en-us/conditions/cancers/cancer-treatments.html',
#   'retrieved_at': '2025-09-29T18:09:04.907923',
#   'title': 'Cancer Treatments   - Together by St. Jude™',
#   'section': 'Featured resources',
#   'super_section': None,
#   'source_idx': 1,
#   'chunk_idx': 1},
#  {'source_url': 'https://together.stjude.org/en-us/conditions/cancers/cancer-treatments.html',
#   'retrieved_at': '2025-09-29T18:09:04.907923',
#   'title': 'Cancer Treatments   - Together by St. Jude™',
#   'section': 'Research Spotlight',
#   'super_section': None,
#   'source_idx': 2,
#   'chunk_idx': 0},
#  {'source_url': 'https://together.stjude.org/en-us/conditions/cancers/cancer-symptoms-side-effects.html',
#   'retrieved_at': '2025-09-29T18:09:05.128189',
#   'title': 'Cancer Symptoms and Side Effects - Together by St. Jude™',
#   'section': 'Learn about managing your child’s symptoms and side effects',
#   'super_section': None,
#   'source_idx': 3,
#   'chunk_idx': 0}]

# %% [markdown]
# ### Embedding

# %%
if torch.cuda.is_available():
    device = "cuda"
else:
    device = "cpu"

print(f"Setting device to '{device}'")
# Out:
# Setting device to 'cuda'

# %%
from typing import List
# Use a pre-trained Sentence-BERT model to convert each chunk into a semantic vector
# embedder = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
# embedder = HuggingFaceEmbeddings(model_name="thenlper/gte-small")

def embed_chunk_docs(chunk_docs: List[str],
                     model_name: str = "sentence-transformers/all-MiniLM-L6-v2",
                     normalize: bool = True):
    """
    Embed chunks of documents based on a given model name.
    """

    embedder = HuggingFaceEmbeddings(
    model_name= model_name,
    encode_kwargs={"normalize_embeddings": normalize})

    embeddings = embedder.embed_documents(chunk_docs)

    return embedder, embeddings

# %%
# embedder, embeddings = embed_chunk_docs(all_chunks, "intfloat/e5-large-v2", True)
# embedder, embeddings = embed_chunk_docs(all_chunks, "sentence-transformers/all-MiniLM-L6-v2", True)
embedder, embeddings = embed_chunk_docs(all_chunks, "sentence-transformers/paraphrase-MiniLM-L6-v2", True)

# %%
len(embeddings)
# Out:
# 6346

# %%
len(embeddings[0])
# Out:
# 384

# %% [markdown]
# ### Store Embeddings in Chroma DB

# %%
# !rm -rf ./chroma_scifact

# %%
from langchain_chroma import Chroma
# from langchain.vectorstores import Chroma
from langchain.embeddings.base import Embeddings
import time
from pathlib import Path
from typing import Optional, Union


def store_embed_in_db(texts: List[str],
    metas: List[dict],
    embedder: Optional[Embeddings] = None,
    persist_directory: Optional[Union[str, Path]] = None
) -> Chroma:
    """
    Store text chunks (and their embeddings) in a Chroma vector database.

    You must provide *either* `embeddings` (precomputed) *or* an `embedder`
    (model that implements .embed_documents).

    Args:
        texts: List of text chunks to index.
        embedder: Optional Embeddings object; used to compute embeddings on the fly.
        persist_directory: Directory where the Chroma DB will be saved.
            If None, a timestamped folder will be created.

    Returns:
        A Chroma vector store instance with your texts indexed.
    """

    if embedder is None:
        raise ValueError("You must supply an `embedder`")

    if persist_directory is None:
        ts = int(time.time())
        persist_directory = Path(f"./chroma_scifact_run_{ts}")
    persist_directory = Path(persist_directory)

    all_metas = df_chunks['metadata'].tolist()


    db = Chroma.from_texts(
        texts=texts,
        embedding=embedder,
        metadatas = metas,
        persist_directory=str(persist_directory)
    )

    print("Chunks successfully stored in Chroma vector DB.")

    return db

# %%
db = store_embed_in_db(all_chunks, all_metas, embedder = embedder)
# Out:
# Chunks successfully stored in Chroma vector DB.

# %%
import pickle
from langchain.vectorstores import Chroma

# Assume vectordb = Chroma(...)
db.persist()  # writes to vectordb._persist_directory

# Save just the persist_directory path
with open("chroma_store.pkl", "wb") as f:
    pickle.dump(db._persist_directory, f)

print("Chroma DB persisted and path saved to pickle.")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_36/2097802540.py in <cell line: 0>()
#       3
#       4 # Assume vectordb = Chroma(...)
# ----> 5 db.persist()  # writes to vectordb._persist_directory
#       6
#       7 # Save just the persist_directory path
#
# AttributeError: 'Chroma' object has no attribute 'persist'

# %%
col = db._collection  # the underlying chromadb Collection
data = col.get()

# %%
len(data['documents'])
# Out:
# 6346

# %%
meta_section_set = set()

for meta in all_metas:
    meta_section_set.add(meta.get('section', ''))

# %%
meta_section_set
# Out:
# {'Storing essential oils',
#  'Risk factors for kidney tumors',
#  'Why You Should Get Your Flu Vaccine',
#  'Ways to prevent foodborne illness',
#  'What is low-grade glioma (LGG)?',
#  'Rotavirus',
#  'Symptoms of AIHA',
#  'Support for new patient families',
#  'Symptoms of kidney tumors',
#  'What is parenteral nutrition?',
#  'Living with hemophilia',
#  'Managing Pain Without Medicine - Together by St. Jude™',
#  'What is health insurance?',
#  'Clinical research volunteers',
#  'How is a modified barium swallow test used?',
#  'Plasma treatments',
#  'Before massage therapy',
#  'How to preventCandidainfection',
#  'Possible side effects of leukapheresis',
#  'Stages of melanoma',
#  'As a colleague',
#  'Screening and planning',
#  'Thursday',
#  'Symptoms of hereditary spherocytosis',
#  'What are the breast cancer screening guidelines for survivors?',
#  'Health Insurance Marketplace',
#  'Long tubes',
#  'Possible side effects\xa0of the low-dose ACTH stimulation test',
#  'Change positions often',
#  'NG tube (nasogastric), NJ tube (nasojejunal), and ND tube (nasoduodenal)',
#  'Checking for safety',
#  'Helping your child cope with eye removal surgery',
#  'How aplastic anemia is classified',
#  'Chemotherapy for astrocytoma',
#  'VIII. What is psychosocial information?',
#  'Co-pays',
#  'Should my child have genetic testing?',
#  'Staging of oligodendroglioma',
#  'Projects to help children grieve and remember',
#  'Review your medical history',
#  'Tips for dry mouth',
#  'What is osteosarcoma?',
#  'Key points about blood counts and sickle cell disease',
#  'What is Burkitt lymphoma?',
#  'Key points about photopheresis',
#  'How pain medicines are given',
#  'Tests for G6PD deficiency',
#  'Possible risks of CT scans',
#  'Professional ocular prosthesis cleaning',
#  '1. Clean your work area and gather supplies',
#  'What is TTP?',
#  'How a CBC test works',
#  'Metal detector at the treatment center',
#  'Protect your child from germs',
#  'Key points about ITP',
#  'How to prepare for an evaluation',
#  'Essential support in a difficult time',
#  'Tonsil and adenoid removal',
#  'Late effects',
#  'Meet your patient representative',
#  'Support for patients with acute myeloid leukemia',
#  'Treatment for chronic myeloid leukemia',
#  'Brain health after craniopharyngioma',
#  'Giving feedback',
#  'Key points about lymphoblastic lymphoma',
#  'Help for mental symptoms',
#  'Autoimmune hepatitis',
#  'Cost and availability',
#  'Why boundaries are important',
#  'Common Infections in Children with Weak Immune Systems - Together by St. Jude™',
#  'Types of mental health providers',
#  'Benefits of complementary approaches',
#  'Posterior fossa syndrome after medulloblastoma surgery',
#  'VII. What are psychotherapy notes?',
#  'General care',
#  'Diagnosis of leukemia',
#  'Learn about care management, insurance, and mental health',
#  'Topical treatments for plantar warts',
#  'Support for patients with pleuropulmonary blastoma',
#  'Tips to reduce phosphorus in your child’s diet',
#  'Diagnosis of adrenocortical tumors',
#  'Dental Problems in Childhood Cancer Survivors - Together by St. Jude™',
#  'Advance directives',
#  'Germ cell tumors in teens and young adults',
#  'What is rhabdomyosarcoma?',
#  'Alternative tests',
#  'Snacks',
#  'Diagnostic Imaging Scans with Anesthesia - Together by St. Jude™',
#  'GVHD Diet Phase 3 Foods - Together by St. Jude™',
#  'Moisturizing during radiation',
#  'Key points about bone marrow aspiration and biopsy',
#  'Medicines your child may take at home',
#  'Know what activities to avoid',
#  'What GINA does not protect',
#  'Living with a feeding tube',
#  'What is therapeutic plasma exchange?',
#  'Radiation oncologist',
#  'Medicine support',
#  'Important documents to bring',
#  'Global Platform for Access to Childhood Cancer Medicines',
#  'Treatment of medulloblastoma',
#  'Other Factors',
#  'How your care team can help',
#  'Familial adenomatous polyposis',
#  'Key points about diagnostic imaging scans with anesthesia',
#  'Caring for your child’s conformer (eye device)',
#  'Prescription coverage',
#  'Safety of biofeedback',
#  'Prognosis for germ cell tumor',
#  'Know your risks and pay attention to your health',
#  'Types of genetic tests',
#  'Symptoms of hemophilia',
#  'Radiation therapy for craniopharyngioma',
#  'Key points about hemophilia',
#  'Chemotherapy and radiation',
#  'Key points about diaper rash',
#  'What do I need to do before my child’s bone scan?',
#  'What is CAR T-cell therapy?',
#  'Diseases autologous transplants treat',
#  'How SGRT works',
#  'Symptoms of heart disease',
#  'Types of blood chemistry studies',
#  'Tips for sore mouth and throat',
#  'What is an ACTH (cosyntropin) stimulation test?',
#  'Ways to prevent infection',
#  'Treatment of NRSTS',
#  'Common Table',
#  'Care after a vaccine',
#  'Higher potassium foods (more than 200 mg per serving)',
#  'Out-of-pocket costs for medicines',
#  'What is DPYD?',
#  'Cytomegalovirus (CMV)',
#  'Laparoscopic splenectomy',
#  'Support for patients with low-grade glioma',
#  'Immature teratomas (cancerous)',
#  'Vac lock bag',
#  'Staging of NRSTS',
#  'Talking about death',
#  'Monitoring for recurrence',
#  'What to expect during the stem cell transplant',
#  'An exception to fasting guidelines: PET Scans',
#  'What is art therapy?',
#  'Resources for Families',
#  'Genetic conditions that cause MDS',
#  'Diagnosis of low-grade glioma',
#  'Treatment of choroid plexus tumors',
#  'Blood infections in childhood cancer patients',
#  'Radiation side effects',
#  'How to Prevent MDROs',
#  'Key points about COVID-19 and fever',
#  'Cost of BEST services',
#  'Cooperate',
#  'Hepatocellular carcinoma',
#  'Parenting Siblings of a Child with a Serious Illness - Together by St. Jude™',
#  'What to do if coverage is denied',
#  '22-66 pounds',
#  'Patient safety information',
#  'Grading and staging of astrocytoma',
#  'How to care for a central line',
#  'How chemotherapy works',
#  'Types of ITP',
#  'Injectable chemotherapy',
#  'What happens in an autopsy?',
#  'Types of childhood astrocytomas and gliomas',
#  'Hereditary neuroblastoma',
#  'Growth factor medicines',
#  'Catheter-associated urinary tract infection (CAUTI)',
#  'Precocious puberty signs and symptoms',
#  'Special transport requests',
#  'Minimal residual disease and ALL',
#  'How to preventC. diffinfection',
#  'Radiation therapy for high-grade glioma',
#  'How the medicines work',
#  'Treatment for juvenile myelomonocytic leukemia',
#  'Surgery to remove the gallbladder (cholecystectomy)',
#  'Prescription medicines',
#  'IN THE KNOW',
#  'Possible risks of a CBC test',
#  'Books on Grief',
#  'Enlarged spleen',
#  'Stages of differentiated thyroid cancer',
#  'Radiation therapy for gliomatosis cerebri',
#  'Symptoms of renal cell carcinoma',
#  'Types of insurance plans',
#  'Diagnosis of acute myeloid leukemia',
#  'Questions to ask about digestive late effects',
#  'Safety reminders for oral syringes',
#  'How to give your child a CHG treatment',
#  'For children and teens',
#  'Less than 22 pounds',
#  'Staging of osteosarcoma',
#  'Types of immunity',
#  'Foods that increase the absorption of iron',
#  'Avoid high-risk foods',
#  'How cognitive problems affect school and daily life',
#  'Risk factors for nosebleeds',
#  '8 years to 18 years and older',
#  'Skin Care and Radiation Therapy - Together by St. Jude™',
#  'Are there things people with Li-Fraumeni syndrome can do to prevent cancer?',
#  'Taking temperature by mouth (oral temperature)',
#  'Preparation of specimen',
#  'I. Our Responsibilities:',
#  'After gene therapy',
#  'Use lip balm',
#  'Challenges health care agents face',
#  'Tri Delta Place parking',
#  'Prognosis for neuroblastoma',
#  'What isCandidainfection?',
#  'TPMT function',
#  'For More Information',
#  'Handicapped parking',
#  'What is surface guided radiation therapy?',
#  'Tips for choosing foods higher in fat',
#  'Types of acute myeloid leukemia in children',
#  'Symptoms of Burkitt lymphoma',
#  'Interpreter services',
#  'Key points about sickle cell disease',
#  'Key points about keeping up with school',
#  'Risk factors\xa0for primary mediastinal large B-cell lymphoma',
#  'Prepare your work area',
#  'Key points about TPMT and NUDT15',
#  'Patient screening',
#  'Ewing sarcoma risk factors',
#  'Types of complementary approaches',
#  'Next 2-4 months',
#  'Tips for Parents',
#  'Stem cell (bone marrow) transplant',
#  'Are nerve blocks safe?',
#  'Treatment summary',
#  'Diagnosis of central adrenal insufficiency',
#  'Diagnosis of optic pathway glioma',
#  'Risk factors of pineoblastoma',
#  'Suicide in children and teens',
#  'Physical support',
#  'How to prepare for the low-dose ACTH stimulation test',
#  'Acupuncture side effects',
#  'Learn about possible long-term effects of cancer treatment',
#  'Staging of retinoblastoma',
#  'Help siblings of the child who died',
#  'Exam under anesthesia',
#  'XII. Being listed in the hospital directory',
#  'X-linked lymphoproliferative syndrome',
#  'Symptoms of a blood product transfusion reaction',
#  'Can I correct a mistake I see in my medical records?',
#  'Alpha cradle',
#  'Proton Beam Radiation for Pediatric Cancer Patients - Together by St. Jude™',
#  'After the CT scan',
#  'Risk factors for melanoma',
#  'Support for patients with primary mediastinal large B-cell lymphoma',
#  'Grief and depression',
#  'Causes of pancytopenia',
#  'What is a nerve block?',
#  'Cognitive behavioral therapy and learning interventions',
#  'Blood culture results',
#  'Grief Camps',
#  'Key points about bladder late effects',
#  'Prognosis for hemolytic anemia',
#  'Thyroid Problems After Childhood Cancer Treatment - Together by St. Jude™',
#  'Skin Problems in Childhood Cancer Survivors - Together by St. Jude™',
#  'Preventing germs from spreading to others',
#  'Symptoms of Hodgkin lymphoma',
#  'Types of liver cancer',
#  'Diagnostic workup, treatment prep',
#  'Brain tumor signs and symptoms include:',
#  'Key points about flu',
#  'Foods to eat and foods to avoid for better cholesterol',
#  'How to clean the thermometer',
#  'Problems and side effects of parenteral nutrition',
#  'What is alpha thalassemia trait?',
#  'Key points about the CAH stimulation test',
#  'Symptoms of depression in children and teens',
#  'When to contact a health care provider',
#  'Palliative care and quality of life',
#  'Learn more',
#  'Contact Housing and Patient Services',
#  'SurNet: A Global Network for',
#  'Cat-Cow pose',
#  'Encourage new foods',
#  'Shuttles',
#  'The flu and COVID-19',
#  'Changes in doctor visits and prescription use',
#  'Causes of von Willebrand disease',
#  'Female Reproductive Problems in Childhood Cancer Survivors - Together by St. Jude™',
#  'What to expect during a CT scan',
#  'Side Effects of TLI',
#  'Types of wounds',
#  'Key points about MIBG scans',
#  'Proton Beam Radiation',
#  'How common is DICER1 syndrome?',
#  'Diagnosis of melanoma',
#  'Symptoms of HHV-6 infection',
#  'What is venipuncture?',
#  'Locations',
#  'What happens during a bone scan?',
#  'Treatment of HHV-6 infection',
#  'Conditioning treatment (chemotherapy)',
#  'Treatment of non-Hodgkin lymphoma',
#  'How chickenpox spreads',
#  'Epstein-Barr virus in children with weak immune systems',
#  'XV. When is my consent not required?',
#  'How common is Li-Fraumeni syndrome?',
#  'What is hemophilia?',
#  'Medicines for procedure-related pain relief',
#  'Bone marrow',
#  'Why children need the HPV vaccine',
#  'After the bone marrow aspiration and biopsy',
#  'What is relapsed/ refractory ALL?',
#  'Living with von Willebrand disease',
#  'Types of craniopharyngioma',
#  'Tips for communication',
#  'Provide and Request Information',
#  'Diagnosis of craniopharyngioma',
#  'Pediatric Cancer Care Team - Together by St. Jude™',
#  'Stem cell mobilization and collection',
#  'Key points about primary mediastinal large B-cell lymphoma',
#  'Risk factors for germ cell brain tumors',
#  'Pre-surgical preparation',
#  'Questions to ask about second cancers',
#  'Noonan syndrome',
#  'Be aware of infection sources',
#  'Sleep safely in the hospital.',
#  'Ways to use mindfulness',
#  'Inpatient Room Service Daily Dinner Special',
#  'Anti-nausea medicine',
#  'Get involved with Child Life at St. Jude',
#  'Diagnosis of a parvovirus infection',
#  'How a biofeedback session works',
#  'Patient-controlled regional anesthesia (PCRA)',
#  'Possible risks of blood chemistry studies',
#  'Causes ofCandidainfection',
#  'Key points about the pediatric hematology care team',
#  'TCD results',
#  'Wear comfortable clothes',
#  'Key points about hepatitis',
#  'Phase 1',
#  'After an endoscopy',
#  'Risk factors for high-grade glioma',
#  'Care planning',
#  'Risk factors for opioid misuse and addiction',
#  'Reminders for oral health',
#  'Symptoms of hereditary persistence of fetal hemoglobin',
#  'Symptoms of low-grade glioma',
#  'Learn more about eye care',
#  'Learn about blood disorders in children and adolescents',
#  'Risk of depression in children and teens with serious illness',
#  'Treatment for plantar warts',
#  'Neuroblastoma risk groups',
#  'What is retinoblastoma?',
#  'Risk factors for medullary thyroid cancer',
#  'Key points about allogeneic transplant',
#  'Apheresis side effects',
#  'Books for teens grieving the death of a sibling',
#  'Care delivery',
#  'Pre-infusion testing',
#  'Food Safety: How to Prevent Foodborne Illness - Together by St. Jude™',
#  'Concerns with using untrained interpreters',
#  'Red blood cell (RBC) count',
#  'Stages of pressure injuries',
#  'Prognosis for germ cell brain tumors',
#  'Pain treatment',
#  'Subcutaneous novel therapy',
#  'Social Work for Pediatric Patients with Serious Illness - Together by St. Jude™',
#  'What to expect during an x-ray',
#  'Key points about CYP2D6',
#  'Deciding about opioids',
#  'Prognosis for medulloblastoma',
#  'Intrinsic or inherited hemolytic anemias',
#  'Key points about subcutaneous ports',
#  'Find information about medical care',
#  'How to use the evaluation results',
#  'What are medical records?',
#  'Bladder Problems after Childhood Cancer Treatment - Together by St. Jude™',
#  'Informed consent',
#  'Vitiligo',
#  'Using a Sharps Container for Sharp Object Disposal  - Together by St. Jude™',
#  'Radioactive iodine treatment for differentiated thyroid cancer',
#  'Types of depressive disorders',
#  'What is the cancer risk for people with Li-Fraumeni syndrome?',
#  'Explore more resources about child life and learning through play',
#  'Steps to prevent a catheter-associated urinary tract infection',
#  'Casual Care',
#  '4 stages of Medicare Part D',
#  'What to expect during a DEXA scan',
#  'Natural killer cells',
#  'Learn more about end-of-life care',
#  'How to prevent aspergillosis',
#  'Related factsheet',
#  'Hyperpigmentation',
#  'SNP chromosome microarray test',
#  'What is a PICC line?',
#  'Treatment of low-grade glioma',
#  'MMR vaccine in children with weak immune systems',
#  'Peripheral Blood Stem Cell (PBSC) Donation\xa0\xa0 - Together by St. Jude™',
#  'Cancer treatments that can cause lung and breathing problems',
#  'What is light therapy?',
#  'How a stem cell transplant works',
#  'Learn about types of infectious diseases',
#  'The Health Insurance Marketplace',
#  'Prepare for shunt emergencies',
#  'Growth Hormone Deficiency in Childhood Cancer Survivors - Together by St. Jude™',
#  'Prognosis for renal cell carcinoma',
#  'The St. Jude School Program | St. Jude Care & Treatment',
#  'Diagnosis of ITP',
#  'Featured resources',
#  'Diagnosis of chronic myeloid leukemia',
#  'Cultural navigation',
#  'Learn more about medications for blood disorders',
#  'Origin and development of acupuncture',
#  'Yoga games for kids and teens',
#  'Key points about vaccines in children with serious illness',
#  'What to expect during the blood chemistry study',
#  'Living with Fanconi anemia',
#  'Symptoms of gliomatosis cerebri',
#  'DPYD function',
#  'How does the endocrine system work?',
#  'Prepare the formula',
#  'Key points about liver cancer',
#  'Which community should I join?',
#  'XVII.\xa0 Request your medical records',
#  'Research spotlight',
#  'Can parents see medical records?',
#  'Diagnosis of acute lymphoblastic leukemia',
#  'Beverages',
#  'Key points about pharmacy insurance',
#  'Key points about relapsed/ refractory ALL',
#  'Symptoms of mpox',
#  'How wounds heal',
#  'Prognosis for medullary thyroid cancer',
#  'What is pancytopenia?',
#  'What is AT/RT?',
#  'What to expect during TBI',
#  'An Unpredictable Disease',
#  'Taking temperature under the arm (armpit or axillary temperature)',
#  '18 months to 4 years old',
#  'Hematology Caregiver Connections:\xa0 Online groups',
#  'What is involved in a bone scan?',
#  'Possible risks or side effects of the stimulation test',
#  'Treatment for measles',
#  'Preparing for Radiation Simulation  - Together by St. Jude™',
#  'What is a gastrostomy?',
#  'Equipment for moving your child',
#  'Questions to ask your care team about music therapy',
#  'Contact',
#  'Percutaneous endoscopic gastrostomy (PEG)',
#  'VRE treatments',
#  'How hemoglobin C trait is inherited',
#  'Test results and making a treatment plan',
#  "4. You have the right to request changes to your child's (your) health information.",
#  'What is Fanconi anemia?',
#  'Meals',
#  'What is Horner syndrome?',
#  'Pediatric Hematology Care Team - Together by St. Jude™',
#  'Online care plan tools',
#  'Chemotherapy for germ cell brain tumors',
#  'Treatment of retinoblastoma',
#  'Condolence letter ending',
#  'Symptoms of giant cell tumors',
#  'Causes of hereditary spherocytosis',
#  'Eat healthy and be active',
#  'Symptoms of NRSTS',
#  'Treatment ofC. diffinfection',
#  'Support for patients with gliomatosis cerebri',
#  'Wear a mask as instructed',
#  'Mucosal barrier injury',
#  'Special precautions for dental work',
#  'Talking to your child about radiation',
#  'What is hemolytic anemia?',
#  'Key points about gene therapy for sickle cell disease',
#  'Understanding and signing consent forms',
#  'Causes of central adrenal insufficiency',
#  'Types of music therapy',
#  'Condolence letter opening',
#  'Radiation therapy for low-grade glioma',
#  'Risk factors for hemoglobin E trait',
#  'Other factors that may increase the risk of vision problems',
#  'Eat out safely',
#  'Cancer treatments that may affect male health',
#  'Be your child’s advocate',
#  'Symptoms of choroid plexus tumor',
#  'Consent Forms - St. Jude Children’s Research Hospital',
#  'Mobilization of stem cells',
#  'Safety reminders for CHG treatments',
#  'Bone marrow stimulant medicines',
#  'Diagnosis of chickenpox',
#  'Support for infants with ALL',
#  'Support for patients with germ cell brain tumors',
#  'Symptoms of germ cell tumor',
#  'Key points about pressure injuries',
#  'Symptoms of lymphoblastic lymphoma',
#  'Key points about Epstein-Barr virus',
#  'Diagnosis of neurogenic bladder',
#  'Nutrition Tips for Picky Eaters  - Together by St. Jude™',
#  'Questions to ask your child’s care team',
#  'Radiation tattoos and marks',
#  'Treatment of Wilms tumor',
#  'Questions?',
#  'Key points about alpha thalassemia trait',
#  'For more information',
#  'Treatment of anaplastic large cell lymphoma',
#  'What are essential oils?',
#  'Key points about your child’s Ommaya reservoir',
#  'Hereditary retinoblastoma and future cancer risk',
#  'Future of immunotherapy in childhood cancer',
#  'Checking for fever is important in COVID-19',
#  'Symptoms of central adrenal insufficiency',
#  'How to make a Best concierge request',
#  'What are pressure injuries?',
#  'High-fat foods',
#  'Surgery for astrocytoma',
#  'Cutaneous continent diversion',
#  'Living with pancytopenia',
#  'Common fears and misconceptions about cancer',
#  'Tests for alpha thalassemia',
#  'Mindfulness and Spiritual Care for Kids in the Hospital',
#  'How the thyroid gland works',
#  'Why does my child need to move and change positions at home?',
#  'Key points about how to protect your child’s skin',
#  'How to arrange leave',
#  'Adaptive immunity',
#  'Friends and family',
#  'Finding Strength in the Melodies',
#  'Chemotherapy for gliomatosis cerebri',
#  'People who can help families navigate financial aspects of care',
#  'Help for physical symptoms',
#  "Questions to ask your child's care team",
#  'Key points about blood disorders',
#  'What to expect during a blood transfusion',
#  'What is chemotherapy?',
#  'What does a child life specialist do?',
#  'Coverage amounts',
#  'What is a biopsy?',
#  'External Ventricular Drain or Shunt - Together by St. Jude™',
#  'What is a leuprolide stimulation test?',
#  'Proton beam radiation vs. conventional radiation',
#  'Tuberous sclerosis complex',
#  'Dental Care for Childhood Cancer Patients - Together by St. Jude™',
#  'Open the package',
#  'Opioids and pregnancy',
#  'A trait is different from a disease',
#  'Risk factors for beta thalassemia trait',
#  'What is differentiated thyroid cancer?',
#  'Neural hearing loss',
#  'Learn more about spirituality and faith',
#  'How to prevent nosebleeds',
#  'Health insurance assistance programs',
#  'How RSV spreads',
#  'Prevention of melanoma',
#  'How medical play can help my child',
#  'Where will we eat?',
#  'Surgery for craniopharyngioma',
#  'Sexual problems',
#  'What problems can occur',
#  'Specimen section',
#  'What not to bring',
#  'Symptoms of medulloblastoma',
#  'After the colonoscopy',
#  'Social anxiety disorder',
#  'Side effects of acute lymphoblastic leukemia treatment',
#  'Causes of hereditary persistence of fetal hemoglobin',
#  'Natural products and nutritional approaches',
#  'Types of giant cell tumors',
#  'Why surgery is needed',
#  'Asking what happens after death',
#  'XVII. What if I have a question or complaint?',
#  'Telangiectasias',
#  'Prognosis for central adrenal insufficiency',
#  'Support system',
#  'Give your child choices when it’s possible',
#  'Offer practical help to a grieving family',
#  'What is liver cancer?',
#  'Key points about dysfibrinogenemia',
#  'Foods with high amounts of phosphorus',
#  'Types of advance directives',
#  'What is pleuropulmonary blastoma?',
#  'Key points about whooping cough',
#  'Vitamin and nutrition supplements',
#  'What is diffuse large B-cell lymphoma?',
#  'Surgery to remove the spleen (splenectomy)',
#  'Risk factors for RSV',
#  'What is\xa0Hodgkin lymphoma?',
#  'Liver Late Effects in Childhood Cancer Survivors - Together by St. Jude™',
#  'Your Child Life team',
#  'Splenectomy',
#  'Skin changes due to neutropenia',
#  'Is there a treatment for DICER1 syndrome?',
#  'Reducing pain',
#  "What's Child Life?",
#  'Where to go for help with out-of-pocket expenses',
#  'Policy number',
#  'What are blood disorders?',
#  'Caring for your child after allogeneic transplant',
#  'Orthotopic neobladder',
#  'How to prepare for the stimulation test',
#  'Keep skin clean and moisturized',
#  'Grains (serving size: 1/2 cup)',
#  'Know Your Risks and Monitor Your Health',
#  'What is medullary thyroid cancer?',
#  'Ewing Sarcoma - Together by St. Jude™',
#  'Diagnosis of HIV',
#  'Key points about fasting guidelines',
#  'Diagnosis of gliomatosis cerebri',
#  'Private health insurance',
#  'Foods with low amounts of phosphorus',
#  'What is non-Hodgkin lymphoma?',
#  'Other reminders:',
#  'Care after the procedure',
#  'What is hemoglobin D trait?',
#  'Vision problems that may occur after cancer treatment',
#  'Support with grief',
#  'Will My Children Get Cancer - Together by St. Jude™',
#  'Biopsy results',
#  'Arrangements at home',
#  'Learn about clinical trials for children',
#  'Medical care for frequent or severe nosebleeds',
#  'Before the splenectomy',
#  'Eye Care - Together by St. Jude™',
#  'Choosing an essential oil product',
#  'Key points about covering out-of-pocket expenses',
#  'Reasons for splenectomy',
#  'Bone marrow aspiration and biopsy',
#  'Visitors',
#  'Cytomegalovirus and bone marrow transplant',
#  'Key points about RSV',
#  'Stop calcium supplements',
#  'Hereditary retinoblastoma',
#  'Central venous device',
#  'Side effects from apheresis medicines',
#  'Age',
#  'How often to take a temperature to check for COVID-19',
#  'Factors that affect chance of medulloblastoma cure',
#  'What is aplastic anemia?',
#  'High-dose chemotherapy with stem cell transplant',
#  'Doppler ultrasound',
#  'Ways to help lower costs of medicines',
#  'Key points about CYP2C19',
#  'Who performs a VCUG?',
#  'Ways to give enteral feedings',
#  'Key points about finding a mental health provider',
#  'Symptoms of ITP',
#  'If you notice any signs of shunt malfunction or infection, call for help right away, day or night:',
#  'What is an allogeneic transplant?',
#  'Risk of central line infection in children with cancer',
#  'Questions about medical care in a clinical trial',
#  'Key points about end-of-life care',
#  'Key points about pain management',
#  'Benefits of a CBC test',
#  'Prognosis for diffuse large B-cell lymphoma',
#  'Key points about CT scans',
#  'Early side effects of TBI',
#  'Getting ready for a blood chemistry study',
#  'Guidelines for hospital shuttle bus use',
#  'What is a splenectomy?',
#  'Heat treatment in the hospital',
#  'What is considered a fever?',
#  'Risk factors for choroid plexus tumor',
#  'TPMTgene groups',
#  'What is a peripheral IV?',
#  'Risk factors for gliomatosis cerebri',
#  'Living with sickle cell disease',
#  'POP OF ART',
#  'Cardiac (Heart) Late Effects in Childhood Cancer Survivors - Together by St. Jude™',
#  'Medicines for neuropathic pain',
#  'Symptoms of CML',
#  'How to scoot your child up in bed',
#  'Hemoglobin',
#  'Diagnosis of juvenile myelomonocytic leukemia',
#  'Learn about different medicines and how to manage them',
#  'Diagnosis of AIHA',
#  'Placement of ND or NJ Tubes: What to Expect',
#  'Social Work | St. Jude Care & Treatment',
#  'When to call your doctor',
#  'Decide who will tell your child and when',
#  'What is a research hospital?',
#  'A, B, E, and S designations',
#  'Living with an inherited risk for cancer',
#  'Symptoms of liver cancer',
#  'Key points about infant ALL',
#  'Heat treatment at home',
#  'Eating and drinking',
#  'CYP2D6 gene groups',
#  'Nutrition in children with feeding tubes',
#  'How to move your child from sitting on the bed to a chair',
#  'How are feeding tubes placed?',
#  'Reasons for an autopsy',
#  'What is an Ommaya reservoir?',
#  'Does it hurt to die?',
#  'How VRE spreads and causes illness',
#  'Health after osteosarcoma',
#  'Symptoms of aspergillosis',
#  'When to transition to adult health care',
#  'Key points about measles',
#  'Targeted Therapies',
#  'II. What is "protected health information" (PHI)?',
#  'Ways to give chemotherapy',
#  'Eligible employees',
#  'Stages of diffuse large B-cell lymphoma',
#  'Treatment of differentiated thyroid cancer',
#  'Enteral feeding at home',
#  'Mesoblastic nephroma or congenital mesoblastic nephroma',
#  'Risk factors for hemoglobin C trait',
#  'Basics of Blood',
#  'What is autoimmune hemolytic anemia?',
#  'Prognosis of leukemia',
#  'Supportive care and clinical services',
#  'Ewing sarcoma symptoms',
#  'Supporting your child during transplant',
#  'Supportive care',
#  'Chickenpox and shingles',
#  'Medicines and MIBG scans',
#  'What is leukemia?',
#  'Diagnosis and treatment of central line infection',
#  'What are kidney tumors?',
#  'How to use the mouthrinse',
#  'Stem cell collection (harvesting)',
#  'Skin reactions and care',
#  'How to use essential oils safely',
#  'White blood cell (WBC) count',
#  'Maintenance/continuation phase',
#  'The autopsy report',
#  'How healthy cells become cancer cells',
#  'When proton beam radiation therapy is used',
#  'Treatments for metastatic retinoblastoma',
#  'Community and Educational Resources',
#  'Staging of germ cell brain tumors',
#  'What is a wound?',
#  'Skin care tips for patients and families',
#  'Finding out about your family history of cancer',
#  'Chemotherapy for high-grade glioma',
#  'Write down information about your child’s nurses.',
#  'During an upper GI exam',
#  'How to position a child in a chair',
#  'Vision Problems in Childhood Cancer Survivors  - Together by St. Jude™',
#  'Early signs and symptoms',
#  'Mature teratomas (noncancerous)',
#  'Home care on the day after toenail removal',
#  'Diagnosis of Epstein-Barr virus infection',
#  'Relapsed disease',
#  'Surgery for gliomatosis cerebri',
#  'How a blood culture works',
#  'Multiple endocrine neoplasia type 1',
#  'Other therapies',
#  'Iron overload diagnostic tests',
#  'Learn about tests to diagnose and monitor diseases',
#  'Fertility counseling',
#  'Lower potassium foods (less than 200 mg per serving)',
#  'Taking a forehead temperature using a temporal artery thermometer',
#  'Symptoms of foodborne illness',
#  'Key points about biopsy',
#  'Keeping skin clean during radiation',
#  'Insurance and access to care',
#  'Emotional and social support',
#  'Genetic Information Nondiscrimination Act (GINA)',
#  'Prognosis for pineoblastoma',
#  'Treatment of mpox',
#  'Symptoms of ependymoma',
#  'What is immunotherapy?',
#  'Types of medulloblastoma',
#  'Safety of DEXA scans',
#  'On the cutting edge of pediatric cancer research, development and funding',
#  'Can children and teens get acupuncture?',
#  'Keeping up with school',
#  'Key points about TCD and TCDi',
#  'More from Together',
#  'Support for patients with non-Hodgkin lymphoma',
#  'Risks',
#  'Dealing with pain after oral surgery',
#  'Chemotherapy for optic pathway glioma',
#  'Key points about health insurance',
#  'How palliative care can help',
#  'Learn about pediatric palliative care',
#  'Key points about medulloblastoma',
#  'What is TPMT?',
#  'Surgery for Childhood Cancer - Together by St. Jude™',
#  'Advantages of a subcutaneous port',
#  'What is Epstein-Barr virus (EBV)?',
#  'What is G6PD deficiency?',
#  'Ongoing effects of sickle cell disease',
#  'Cancers of the blood',
#  'Key points about pleuropulmonary blastoma',
#  'Removing an eye prosthesis',
#  'Common stomach viruses: Rotavirus and norovirus',
#  'Types of central lines',
#  'Let’s Cheer: Transplant Cures Teen’s Aplastic Anemia',
#  'Questions to ask about acute lymphoblastic leukemia',
#  'Vegetables (serving size: 1/2 cup)',
#  'Manufacturing CAR T cells',
#  'Nevoid basal cell carcinoma syndrome',
#  'Gastrostomy tube (G-tube)',
#  'Watch for signs of infection.',
#  'What to expect with epidural anesthesia',
#  'Common Areas',
#  'More Resources',
#  'How to take part in clinical research',
#  'Side effects caused by blood-thinning medicine',
#  'Symptoms of AT/RT',
#  'Acquired TTP',
#  'Types of pharmacy insurance',
#  'Anthracyclines',
#  'Heart-healthy habits',
#  'What is a congenital adrenal hyperplasia (CAH) stimulation test?',
#  'Contrast studies',
#  'Tips for families',
#  'Key points',
#  'Treatment of undifferentiated embryonal sarcoma of the liver',
#  'Risk factors for diffuse large B-cell lymphoma',
#  'Getting medicine',
#  'Wound vac machine alarms',
#  'Make food healthy and fun',
#  'Contact Us - St. Jude Children’s Research Hospital',
#  'Tips for writing condolence letters',
#  'Key points about social work',
#  'Tips to prevent infection',
#  'Metastasis',
#  'Diagnosis of pancytopenia',
#  'Other patients and families',
#  'Granulation tissue',
#  'What to expect during an iron overload evaluation',
#  'How Does Palliative Care Make a Difference?',
#  'Key points about AT/RT',
#  'Phase 3',
#  'Fibrosis',
#  'Rotavirus in children with illness or weak immune systems',
#  'For parents of babies and toddlers',
#  'Key points about hereditary persistence of fetal hemoglobin',
#  'Treatment of central adrenal insufficiency',
#  'How to store opioid medicines',
#  'Science of art therapy',
#  'Duchenne muscular dystrophy',
#  'Safety Reminders',
#  'Treatments for oral problems',
#  'What is sickle cell trait?',
#  'How urine leaves the body after a cystectomy',
#  'Daily Routines | St. Jude Care & Treatment',
#  'Monday',
#  'Talking to your child about needle sticks',
#  'Key points about germ cell tumor',
#  'About addiction',
#  'Incontinent diversion',
#  'Surgery for high-grade glioma',
#  'Symptoms of non-Hodgkin lymphoma',
#  'What is Li-Fraumeni syndrome?',
#  'Learning about health care',
#  'How to take a temperature',
#  'How to improve communication between family caregivers and the palliative care team',
#  "'Be Proactive'",
#  'What is pharmacy insurance?',
#  'How is pain diagnosed?',
#  'Tinnitus',
#  'Signs of leukemia',
#  'Other questions to ask your care team',
#  'Treatment of brain and spinal tumors',
#  'Types of kidney tumors',
#  'Treatment of infant ALL',
#  'Benefits of PCRA',
#  'Treatment for chickenpox',
#  'What these laws mean for you',
#  'Microscopic description',
#  'How\xa0cytomegalovirus spreads',
#  'What is a PET scan?',
#  'Adjust the gloves',
#  'Strategies to cope with scanxiety',
#  'What to expect during light therapy',
#  'TPMT and NUDT15 function',
#  'Key points about the ACTH stimulation test',
#  'Key points about medullary thyroid cancer',
#  'An autopsy will not affect burial, cremation, or funeral plans',
#  'What to expect after toenail removal',
#  'Core hematology care team',
#  'Treatment of acute myeloid leukemia',
#  'Stages of Burkitt lymphoma',
#  'Risk factors of rhabdomyosarcoma',
#  'Become a health care advocate',
#  'Take steps to prevent illness',
#  'Questions to ask your care team about neurogenic bladder',
#  'What is alpha thalassemia?',
#  'What is DICER1 syndrome?',
#  'Removing bandages at home',
#  'Find more information',
#  'Sepsis: Know the signs',
#  'Oral syringes vs. IV syringes',
#  'Eat a healthy diet and drink plenty of fluids',
#  'Lung problems that may occur after cancer treatment',
#  'How to prevent the spread of rotavirus',
#  'Other foods',
#  'Skin cancer types',
#  'Types of pain medicines',
#  'Diagnosis of hemolytic anemia',
#  'What is neurogenic bladder?',
#  'Nurture the relationship between siblings',
#  'Tests for HHV-6',
#  'Alert others of your child’s condition',
#  'Support',
#  'Hearing loss',
#  'Support during procedures',
#  'Hydroxyurea',
#  'Cancer treatments that may cause vision problems',
#  'Wounds in children with cancer or other serious illness',
#  'Treatment of renal cell carcinoma',
#  'STUDIO 262',
#  'What to expect during an oral glucose tolerance test',
#  'Neurofibromatosis type 2',
#  'Risk factors for differentiated thyroid cancer',
#  'Risk factors for craniopharyngioma',
#  'Pharmacogenomic test results',
#  'How to give heat treatment to your child',
#  'Hyperthyroidism',
#  'Basic metabolic panel (BMP)',
#  'What are DDAVP and Stimate®',
#  'Physical exam and health history',
#  'Common Health Insurance Terms - Together by St. Jude™',
#  'Safety of blood products',
#  'Diagnosis of TTP',
#  'Get to know your child’s wishes',
#  'Key points about an alkaline saline mouthrinse',
#  'Hemoglobin S/HPFH',
#  'Symptoms ofC.\xa0diffinfection',
#  'What is discussed on\xa0St. Jude\xa0Voice?',
#  'What happens in the laboratory',
#  'What is a low-dose ACTH (cosyntropin) stimulation test?',
#  'Coverage amounts, networks, and co-pays',
#  'Prognosis for retinoblastoma',
#  'Penicillin',
#  'Tumors of solid tissue',
#  'How does a VCUG work?',
#  'Help your child transition',
#  'How to prepare for the transition to adult health care',
#  'Medical and treatment history',
#  'Watch for skin changes',
#  'Equipment and supplies that families may need include:',
#  'Tests to Diagnose Infection - Together by St. Jude™',
#  'Key points about a CBC test',
#  'Bladder cancer',
#  'Clean and bandage the wound',
#  'Caring for a subcutaneous port',
#  'Patients who had stem cell transplants',
#  'Aminoglycosides and hearing loss risk',
#  'Prognosis for pleuropulmonary blastoma',
#  'What are the risk factors?',
#  'Condolence letter middle',
#  'What are digestive problems after childhood cancer and stem cell transplant?',
#  'Benefits of gene therapy',
#  'Prepare for a colonoscopy',
#  'How hemoglobin D trait is inherited',
#  'Know your risks and monitor your health',
#  'Surgery for optic pathway glioma',
#  'How apheresis works',
#  'After the biopsy',
#  'Letter from pediatric oncologist',
#  'Help your child remember how to eat by mouth',
#  'Feelings of grief',
#  'Metabolic syndrome after childhood craniopharyngioma',
#  'Should I consider testing for me or my child?',
#  'What is a health care transition?',
#  'Treatment\xa0of cytomegalovirus',
#  'Causes of pressure injuries',
#  'How the female reproductive system works',
#  'What to do if your child is exposed to chickenpox',
#  'What is CLABSI?',
#  'Supportive care after transplant',
#  'Monitoring for return of cancer',
#  'Ways to prevent plantar warts',
#  'After treatment',
#  'Treatment for neurogenic bladder',
#  'Treatment of oligodendroglioma',
#  'What is measles?',
#  'Placement of NG Tubes: What to Expect',
#  'How HPV spreads',
#  'Intrathecal chemotherapy',
#  'Antifibrinolytic medicines',
#  'When to seek genetic testing for cancer',
#  'Mixed hearing loss',
#  'Caring for the Mind and Body',
#  'Diagnosis of giant cell tumors',
#  'Type of ALL',
#  'Causes of pain',
#  'Reminders for parents and family caregivers',
#  'Medications',
#  'Tips for low-fat meals and snacks',
#  'Key points about anaplastic large cell lymphoma',
#  'How is targeted therapy used?',
#  'Key points about cognitive effects',
#  'How HLA typing works',
#  'Questions to ask your care team:',
#  'How to prevent the flu',
#  'Support for patients with AT/RT',
#  'Mindfulness resources',
#  'How parenteral nutrition is given',
#  'VRE (Vancomycin-Resistant Enterococci) - Together by St. Jude™',
#  'Can I see my medical records?',
#  'III. What does "health care operations" include?',
#  'Hematocrit (HCT or PCV)',
#  'Benefits of a central line',
#  'Tyrosine kinase inhibitors for differentiated thyroid cancer',
#  'Symptoms of sickle cell disease',
#  'Finding Hope in Every Cell',
#  'Diagnosis of osteosarcoma',
#  'Caring for a VP shunt',
#  'What patients and families can do',
#  'Diagnosis of von Willebrand disease',
#  'What are tonsils and adenoids?',
#  ...}

# %%
meta_super_section_set = set()

for meta in all_metas:
    meta_super_section_set.add(meta.get('super_section', ''))

# %%
meta_super_section_set
# Out:
# {None}

# %%
# all_metas.get('section', '')

# %% [markdown]
# ## Query-Response Pipeline (RAG)

# %%
# Improved retrieval function with query expansion and better ranking
from langchain.vectorstores.base import VectorStoreRetriever
import re
from typing import List, Tuple, Dict, Any

def expand_query(query: str) -> List[str]:
    """Expand query with related terms for better retrieval"""
    expansions = {
        # Medical terms
        "symptoms": ["signs", "indications", "early signs", "clinical features"],
        "treatment": ["therapy", "management", "care", "intervention"],
        "side effects": ["adverse effects", "toxicities", "complications"],
        "diagnosis": ["testing", "screening", "evaluation"],
        "prognosis": ["outlook", "survival", "recovery chances"],
        "clinical trial": ["research study", "trial", "experimental therapy"],
        # Cancer / disease
        "cancer": ["tumor", "carcinoma", "malignancy", "oncology"],
        "leukemia": ["blood cancer", "ALL", "AML"],
        "lymphoma": ["hodgkin", "non-hodgkin"],
        "infection": ["illness", "disease", "condition", "virus", "bacteria"],
        # Resources
        "meal": ["food", "nutrition", "dining", "cafeteria", "diet"],
        "housing": ["lodging", "accommodation", "place to stay", "family housing"],
        "transportation": ["shuttle", "travel", "ride", "commute", "bus service"],
        "financial": ["cost", "expenses", "billing", "assistance", "funding"],
        "support": ["counseling", "resources", "services", "help", "aid"],
        # Hospital / logistics
        "admission": ["application", "check-in", "eligibility", "requirements"],
        "visitor": ["guest", "family member", "parent", "guardian"],
        "appointment": ["clinic visit", "consultation", "checkup", "follow-up"],
    }

    expanded_queries = [query]
    query_lower = query.lower()

    for key, synonyms in expansions.items():
        if key in query_lower:
            for synonym in synonyms:
                expanded_queries.append(query.replace(key, synonym, 1))

    return expanded_queries

def detect_metadata_filter(query: str) -> Optional[Dict[str, Any]]:
    """
    Look for trigger phrases in the query and return an appropriate
    metadata filter for your vector store.
    """
    q = query.lower()
    # 2) detect_metadata_filter() dictionary
    mapping = {
        # --- St. Jude navigation & new patients ---
        "new patient":      {"section": {"$eq": "Information for New Patients | St. Jude Care & Treatment"}},
        "first visit":      {"section": {"$eq": "Information for New Patients | St. Jude Care & Treatment"}},
    
        # --- Housing ---
        "housing":          {"section": {"$eq": "Housing and Patient Services - St. Jude Children’s Research Hospital"}},
        "target house":     {"section": {"$eq": "Housing and Patient Services"}},
        "tri delta":        {"section": {"$eq": "Housing and Patient Services"}},
        "domino's village": {"section": {"$eq": "Domino's Village Menu"}},
    
        # --- Food services / menus ---
        "kay kafe":         {"section": {"$eq": "Kay Kafe Menu"}},
        "kay cafe":         {"section": {"$eq": "Kay Kafe Menu"}},
        "room service":     {"section": {"$eq": "Room Service Menu - St. Jude Children’s Research Hospital"}},
        "isolation":        {"section": {"$eq": "Isolation To-Go Menu - St. Jude Children’s Research Hospital"}},
        "menu":             {"section": {"$eq": "Kay Kafe Menu"}},
    
        # --- Logistics ---
        "parking":          {"section": {"$eq": "Parking and Construction | St. Jude Care & Treatment"}},
        "directions":       {"section": {"$eq": "Parking and Construction | St. Jude Care & Treatment"}},
        "visitor":          {"section": {"$eq": "Visitors"}},
    
        # --- Patient portal & programs ---
        "mychart":          {"section": {"$eq": "St. Jude MyChart"}},
        "child life":       {"section": {"$eq": "Child Life | St. Jude Care & Treatment"}},
        "school program":   {"section": {"$eq": "The St. Jude School Program | St. Jude Care & Treatment"}},
    
        # --- Clinical trials / research ---
        "clinical trial":   {"section": {"$eq": "Clinical Trials | St. Jude Care & Treatment"}},
        "consent":          {"section": {"$eq": "Understanding and signing consent forms"}},
    
        # --- Policies / legal ---
        "hipaa":            {"title":   {"$eq": "Notice of Privacy Practices (HIPAA) - St. Jude Children’s Research Hospital"}},
        "privacy":          {"section": {"$eq": "Privacy & Legal"}},
        "nondiscrimination":{"section": {"$eq": "Discrimination is against the law"}},
    
        # --- Support services / community ---
        "concierge":        {"section": {"$eq": "Best Upon Request Concierge Service\u202f | St. Jude Care & Treatment"}},
        "st. jude voice":   {"section": {"$eq": "St. Jude Voice: Our Virtual Adviser community | St. Jude Care & Treatment"}},
    
        # --- Treatments ---
        "chemotherapy":     {"section": {"$eq": "Chemotherapy"}},
        "radiation":        {"section": {"$eq": "Radiation therapy"}},
        "surgery":          {"section": {"$eq": "Surgery"}},
        "targeted therapy": {"section": {"$eq": "Targeted therapy"}}
}

   

    for trigger, filt in mapping.items():
        if trigger in q:
            return filt
    return None


def retrive_top_k_docs_improved(selected_query: str,
                               db_retriever: VectorStoreRetriever,
                               embedder: Embeddings,
                               k_docs: int = 10,  # Increased from 5
                               lambda_mult: float = 0.3,  # Lower for more similarity focus
                               query_prefix: str = "query: ",
                               doc_prefix: str = "passage: ",
                               use_query_expansion: bool = True):
    """
    Improved retrieval with query expansion and better re-ranking
    """

    if embedder is None:
        raise ValueError("You must supply an `embedder`.")

    # Step 1: Query expansion
    if use_query_expansion:
        expanded_queries = expand_query(selected_query)
    else:
        expanded_queries = [selected_query]

    # Step 2: Auto‐detect a metadata filter
    metadata_filter = detect_metadata_filter(selected_query)

    # Step 3: Retrieve documents for each expanded query with metadata filter
    all_retrieved_docs = []

    for exp_query in expanded_queries:
        formatted_query = f"{query_prefix}{exp_query}"

        # Define retriever method
        retriever = db_retriever.as_retriever(
            search_type="mmr",
            search_kwargs={"k": k_docs,
                           "lambda_mult": lambda_mult,
                          **({"filter": metadata_filter} if metadata_filter else {})}
        )

        # Get relevant documents
        results = retriever.get_relevant_documents(formatted_query)

        # Store documents with their expanded query context
        for doc in results:
            all_retrieved_docs.append((doc.page_content, exp_query))

    # Step 3: Remove duplicates while preserving order
    seen_docs = set()
    unique_docs = []
    for doc_content, exp_query in all_retrieved_docs:
        if doc_content not in seen_docs:
            seen_docs.add(doc_content)
            unique_docs.append((doc_content, exp_query))

    # Step 4: Re-rank all unique documents against original query
    original_formatted_query = f"{query_prefix}{selected_query}"
    query_embed = embedder.embed_query(original_formatted_query)

    # Format documents for embedding
    formatted_retrieved_docs = [f"{doc_prefix}{doc}" for doc, _ in unique_docs]

    # Embed documents
    doc_embeds = embedder.embed_documents(formatted_retrieved_docs)

    # Compute similarity scores
    similarity_scores = cosine_similarity([query_embed], doc_embeds)[0]

    # Step 5: Combine documents with scores and rank
    ranked_docs = []
    for i, (formatted_doc, score) in enumerate(zip(formatted_retrieved_docs, similarity_scores)):
        original_doc, exp_query = unique_docs[i]
        ranked_docs.append((formatted_doc, score, exp_query))

    # Sort by similarity score (descending)
    ranked_docs.sort(key=lambda x: x[1], reverse=True)

    # Step 6: Apply keyword boost for exact matches
    boosted_docs = []
    query_keywords = set(re.findall(r'\b\w+\b', selected_query.lower()))

    for doc, score, exp_query in ranked_docs:
        doc_keywords = set(re.findall(r'\b\w+\b', doc.lower()))
        keyword_overlap = len(query_keywords.intersection(doc_keywords))

        # Boost score based on keyword overlap
        boosted_score = score + (keyword_overlap * 0.05)  # Small boost for keyword matches
        boosted_docs.append((doc, boosted_score, exp_query))

    # Final sort by boosted scores
    boosted_docs.sort(key=lambda x: x[1], reverse=True)

    # Display results
    print("Query:", selected_query)
    print(f"\nExpanded to {len(expanded_queries)} queries")
    print(f"Retrieved {len(unique_docs)} unique documents")
    print(f"\nTop {k_docs} Retrieved Chunks with Scores:\n")

    final_results = []
    for i, (doc, score, exp_query) in enumerate(boosted_docs[:k_docs]):
        print(f"Chunk {i+1} (Score: {score:.4f}, From: '{exp_query}'):")
        print(f"{doc}")
        print(f"{'-'*80}")
        final_results.append((doc, score))

    return boosted_docs[:k_docs]

# %%
# Compare original vs improved retrieval with question selection
QUERIES = {"1": "What are brain and spinal cord tumors?",
           "2": "What are the most uncommon tumors?",
           "3": "What is adrenocortical tumor?",
           "4": "What is Family Commons at St. Jude?"}

print("Available queries:")
for key, value in QUERIES.items():
    print(f"{key}: {value}")

query_choice = input("Enter number of your query choice: ")
selected_query = QUERIES.get(query_choice)

if selected_query:
    print(f"\nSelected query: {selected_query}")

    print("\n" + "=" * 50)
    print("IMPROVED RETRIEVAL METHOD")
    print("=" * 50)

    result_improved = retrive_top_k_docs_improved(selected_query,
                       db_retriever = db,
                       embedder = embedder,
                       k_docs = 10,
                       lambda_mult = 0.3,
                       query_prefix = 'query: ',
                       doc_prefix = 'passage: ',
                       use_query_expansion = True)
else:
    print("Invalid choice. Please select 1, 2, or 3.")
# Out:
# Available queries:
# 1: What are brain and spinal cord tumors?
# 2: What are the most uncommon tumors?
# 3: What is adrenocortical tumor?
# 4: What is Family Commons at St. Jude?
# Enter number of your query choice:  3
# Selected query: What is adrenocortical tumor?
#
# ==================================================
# IMPROVED RETRIEVAL METHOD
# ==================================================
# Query: What is adrenocortical tumor?
#
# Expanded to 1 queries
# Retrieved 10 unique documents
#
# Top 10 Retrieved Chunks with Scores:
#
# Chunk 1 (Score: 0.8285, From: 'What is adrenocortical tumor?'):
# passage: International Pediatric Adrenocortical Tumors Registry (IPACTR)
# --------------------------------------------------------------------------------
# Chunk 2 (Score: 0.7765, From: 'What is adrenocortical tumor?'):
# passage: Adrenocortical tumor (ACT) is a rare tumor of theadrenal gland. These tumors can bebenignormalignant. You might also hear ACT called:
# Adrenocortical cancer
# Cancer of the adrenal cortex
# Adrenocortical adenoma
# Adrenocortical carcinoma
# The body has 2 adrenal glands, 1 on top of each kidney. The adrenal glands produce hormones such as cortisol and aldosterone. These hormones have important jobs such as:
# Controlling how the body uses carbs, fats, and proteins for energy
# Helping the body cope with stress
# Controlling blood pressure
# Regulating water, potassium, and salt in the body
# The outer layer of the adrenal gland is called the adrenal cortex. The adrenal cortex produces male and female sex hormones calledandrogensandestrogens. These hormones affect the development of male and female traits.
# --------------------------------------------------------------------------------
# Chunk 3 (Score: 0.5731, From: 'What is adrenocortical tumor?'):
# passage: Oligodendroglioma is a type of brain tumor known as aglioma. This tumor gets its name from oligodendrocytes, cells that cover and protect nerves in the brain.
# Oligodendrogliomas can occur most often in thewhite matterof thecerebrum. White matter is a network of pale-colored nerve fibers in the brain. White-matter cells transmit messages from one part of the brain to another.
# About half of all oligodendrogliomas are in the frontal lobe.
# Oligodendrogliomas usually form in the cerebrum.
# Most oligodendrogliomas occur in adults. They are rare in children and teens. These tumors make up less than 1% of brain tumors in children younger than 14.
# --------------------------------------------------------------------------------
# Chunk 4 (Score: 0.5635, From: 'What is adrenocortical tumor?'):
# passage: Yolk sac tumors (also known as endodermal sinus tumor) can be gonadal or extragonadal. They most often occur in the ovaries or testes and make up about 25% of germ cell tumors. It is the most common testicular cancer in boys under 3 years of age. Yolk sac tumors make the hormone alpha-fetoprotein (AFP). The survival rate for childhood yolk sac tumor is over 90%.
# Choriocarcinomas can be gonadal or extragonadal. They make the hormonebeta-human chorionic gonadotropin(β-HCG).
# Embryonal carcinomas can occur in the testicle or other parts of the body. They do not form in the ovary. They can make β-HCG, AFP, or a combination.
# Mixed germ cell tumors can be gonadal or extragonadal. They are made up of malignant germ cell tumor and teratoma.
# --------------------------------------------------------------------------------
# Chunk 5 (Score: 0.5586, From: 'What is adrenocortical tumor?'):
# passage: Atypical teratoid/rhabdoid tumor (AT/RT) is a fast-growing tumor of the brain and spinal cord. It accounts for about 1–2% ofcentral nervous system(CNS) tumors in children. There are about 75–80 new cases of AT/RT each year in the United States. AT/RT most often occurs in young children under age 3. It is the most commonmalignantCNS tumor in infants under 1 year old.
# AT/RT is a tumor that most often develops in the cerebellum and the brain stem.
# AT/RTs can occur throughout the brain and spinal cord. In children, about half of AT/RTs develop in thecerebellumor brain stem. AT/RTs can also spread through thecerebrospinal fluidto other parts of the brain and spinal cord.
# --------------------------------------------------------------------------------
# Chunk 6 (Score: 0.5546, From: 'What is adrenocortical tumor?'):
# passage: SurgerySurgeryto remove the adrenal gland (adrenalectomy) is the main treatment for ACT. The goal of treatment is complete removal (resection) of the tumor. This type of tumor requires special care during surgery. The adrenal gland is delicate and can break apart easily during surgery. If parts of the tumor break off, then the chance for spread of the cancer is high. This is why abiopsyis not usually used to diagnose ACT before surgery.Planning by expert surgeons familiar with pediatric ACT is highly recommended for children with suspected ACT. A team that includesoncologists,endocrinologistsandanesthesiaspecialists helps before, during, and after surgery. This team helps to manage blood pressure and changes in electrolytes, body fluids, and hormones that the tumor may affect
# --------------------------------------------------------------------------------
# Chunk 7 (Score: 0.5195, From: 'What is adrenocortical tumor?'):
# passage: Blood and urine levels of electrolytes such as sodium, calcium, and potassium
# Urine output and concentration
# Tumor markers, includingalpha-fetoproteinandbeta-human chorionic gonadotropinto rule out agerm cell tumor
# Aneurological examto measure brain function. This includes memory, vision, hearing, muscle strength, balance, coordination, and reflexes.
# Imaging testssuch ascomputed tomography(CT) andmagnetic resonance imaging(MRI) to identify the tumor, its size, and location.
# Tumor tissue analysisfrom abiopsyorsurgeryto check for abnormal cells.
# Cyst fluid analysisfrom surgery to show changes that help identify the tumor.
# --------------------------------------------------------------------------------
# Chunk 8 (Score: 0.5184, From: 'What is adrenocortical tumor?'):
# passage: Prognosis depends on tumor type, the child’s age, and whether the tumor spreads or can be fully removed.
# --------------------------------------------------------------------------------
# Chunk 9 (Score: 0.5092, From: 'What is adrenocortical tumor?'):
# passage: Cancer is named for the type of cell or tissue where it starts. For example,astrocytomastarts in cells calledastrocytes. Andneuroblastomagrows from immature nerve cells called neuroblasts.
# More than 100 types of cancers happen in children. The specific type of cancer is determined by how the cells look under the microscope and the molecular and genetic features of the cells.
# --------------------------------------------------------------------------------
# Chunk 10 (Score: 0.4985, From: 'What is adrenocortical tumor?'):
# passage: Lymphoma is a cancer of thelymphatic system. The lymphatic system is a part of theimmune system. This network of nodes, glands, and vessels moves white blood cells calledlymphocytesaround the body to fight infection.
# Atumorcan begin in several places becauselymphtissue is throughout the body.
# There are two types of lymphoma:
# Hodgkin lymphoma
# Non-Hodgkin lymphoma, includinganaplastic large cell lymphoma (ALCL),Burkitt lymphoma,diffuse large B-cell lymphoma (DLBCL),lymphoblastic lymphoma, andprimary mediastinal large B-cell lymphoma (PMBCL).
# --------------------------------------------------------------------------------

# %%
from langchain.vectorstores.base import VectorStoreRetriever

def create_rag_prompt(selected_query: str,
                       db_retriever: VectorStoreRetriever,
                       embedder: Embeddings,
                       k_docs: int = 5,
                       lambda_mult: float = 0.3,
                       query_prefix: str = "query: ",
                       doc_prefix: str = "passage: ",
                       use_query_expansion: bool = True):
    """
    Retrieve the top-k most relevant chunks for a given query using
    Maximal Marginal Relevance, then re-rank by cosine similarity.

    Args:
        query: Raw query string.
        db_retriever: The `db.as_retriever(...)` object configured with MMR.
        embedder: An Embeddings instance (implements embed_query & embed_documents).
        k: How many chunks to return.
        lambda_mult: MMR diversity parameter (0→pure similarity, 1→pure diversity).
        query_prefix: Text to prepend before embedding the query.
        doc_prefix: Text to prepend before embedding each chunk.

    Returns:
        A list of (chunk_text, score) sorted descending by score.
    """

    if embedder is None:
        raise ValueError("You must supply an `embedder`.")

    # Step 1: Query expansion
    if use_query_expansion:
        expanded_queries = expand_query(selected_query)
    else:
        expanded_queries = [selected_query]

    # Step 2: Auto‐detect a metadata filter
    metadata_filter = detect_metadata_filter(selected_query)

    # Step 3: Retrieve documents for each expanded query with metadata filter
    all_retrieved_docs = []

    for exp_query in expanded_queries:
        formatted_query = f"{query_prefix}{exp_query}"

        # Define retriever method
        retriever = db_retriever.as_retriever(
            search_type="mmr",
            search_kwargs={"k": k_docs,
                           "lambda_mult": lambda_mult,
                          **({"filter": metadata_filter} if metadata_filter else {})}
        )

        # Get relevant documents
        results = retriever.get_relevant_documents(formatted_query)

        # Store documents with their expanded query context
        for doc in results:
            all_retrieved_docs.append((doc.page_content, exp_query))

    # Step 4: Remove duplicates while preserving order
    seen_docs = set()
    unique_docs = []
    for doc_content, exp_query in all_retrieved_docs:
        if doc_content not in seen_docs:
            seen_docs.add(doc_content)
            unique_docs.append((doc_content, exp_query))

    # Step 5: Re-rank all unique documents against original query
    original_formatted_query = f"{query_prefix}{selected_query}"
    query_embed = embedder.embed_query(original_formatted_query)

    # Format documents for embedding
    formatted_retrieved_docs = [f"{doc_prefix}{doc}" for doc, _ in unique_docs]

    # Embed documents
    doc_embeds = embedder.embed_documents(formatted_retrieved_docs)

    # Compute similarity scores
    similarity_scores = cosine_similarity([query_embed], doc_embeds)[0]

    # Step 6: Combine documents with scores and rank
    ranked_docs = []
    for i, (formatted_doc, score) in enumerate(zip(formatted_retrieved_docs, similarity_scores)):
        original_doc, exp_query = unique_docs[i]
        ranked_docs.append((formatted_doc, score, exp_query))

    # Sort by similarity score (descending)
    ranked_docs.sort(key=lambda x: x[1], reverse=True)

    # Step 7: Apply keyword boost for exact matches
    boosted_docs = []
    query_keywords = set(re.findall(r'\b\w+\b', selected_query.lower()))

    for doc, score, exp_query in ranked_docs:
        doc_keywords = set(re.findall(r'\b\w+\b', doc.lower()))
        keyword_overlap = len(query_keywords.intersection(doc_keywords))

        # Boost score based on keyword overlap
        boosted_score = score + (keyword_overlap * 0.05)  # Small boost for keyword matches
        boosted_docs.append((doc, boosted_score, exp_query))

    # Final sort by boosted scores
    boosted_docs.sort(key=lambda x: x[1], reverse=True)

    # Combine the retrieved context into a single block of text
    context = "\n".join([doc for doc, score, exp_query in boosted_docs])

    # Compose the RAG prompt by combining the context and the user's question
    rag_prompt = f"""
You are a helpful healthcare information assistant for families, patients, and caregivers.
You specialize in providing clear, accurate, and supportive information about childhood diseases,
cancer, and St. Jude Children’s Research Hospital.

When answering:
- Always rely on the retrieved documents (disease info pages, hospital resources, treatment guides).
- Present information in clear, compassionate language that non-experts can understand.
- Never provide personal medical advice, diagnoses, or treatment recommendations.
  Instead, encourage patients to consult their doctors for medical concerns.

Answer structure:
If relevant information is found:
- Summarize the key facts clearly and accurately.
- Organize the response with short paragraphs, bullet points, or sections if helpful.
- Cite or mention the source section in natural language (e.g., “According to St. Jude’s page on brain tumors…”).
- Keep the tone supportive and empathetic.
- Please provide answers in English only

Style:
- Use simple, reassuring language.
- Avoid technical jargon unless the retrieved text explicitly includes it.
- Do not speculate or invent facts.

Remember: Your role is to **inform, not advise**. Always guide families toward
qualified healthcare providers for decisions about diagnosis or treatment.


    [CONTEXT]
    {context}
    """

    # Display the final composed prompt that will be passed to the LLM
    print("=== RAG Augmented Prompt ===")
    print(rag_prompt)

    return rag_prompt

# %%
# Define a new query
QUERIES = {"1": "What are the types of common tumors?",
           "2": "What are the most uncommon tumors?",
           "3": "What is adrenocortical tumor??",
           "4": "What is Family Commons at St. Jude?"}

query_choice = input("Enter number of your query choice")
selected_query = QUERIES.get(query_choice)

rag_prompt = create_rag_prompt(selected_query,
                   db_retriever = db,
                   embedder = embedder,
                   k_docs = 10,
                   lambda_mult = 0.3,
                   query_prefix = 'query: ',
                   doc_prefix = 'passage: ',
                   use_query_expansion = True)
# Out:
# Enter number of your query choice 3
# === RAG Augmented Prompt ===
#
# You are a helpful healthcare information assistant for families, patients, and caregivers.
# You specialize in providing clear, accurate, and supportive information about childhood diseases,
# cancer, and St. Jude Children’s Research Hospital.
#
# When answering:
# - Always rely on the retrieved documents (disease info pages, hospital resources, treatment guides).
# - Present information in clear, compassionate language that non-experts can understand.
# - Never provide personal medical advice, diagnoses, or treatment recommendations.
#   Instead, encourage patients to consult their doctors for medical concerns.
#
# Answer structure:
# If relevant information is found:
# - Summarize the key facts clearly and accurately.
# - Organize the response with short paragraphs, bullet points, or sections if helpful.
# - Cite or mention the source section in natural language (e.g., “According to St. Jude’s page on brain tumors…”).
# - Keep the tone supportive and empathetic.
# - Please provide answers in English only
#
# Style:
# - Use simple, reassuring language.
# - Avoid technical jargon unless the retrieved text explicitly includes it.
# - Do not speculate or invent facts.
#
# Remember: Your role is to **inform, not advise**. Always guide families toward
# qualified healthcare providers for decisions about diagnosis or treatment.
#
#
#     [CONTEXT]
#     passage: International Pediatric Adrenocortical Tumors Registry (IPACTR)
# passage: Adrenocortical tumor (ACT) is a rare tumor of theadrenal gland. These tumors can bebenignormalignant. You might also hear ACT called:
# Adrenocortical cancer
# Cancer of the adrenal cortex
# Adrenocortical adenoma
# Adrenocortical carcinoma
# The body has 2 adrenal glands, 1 on top of each kidney. The adrenal glands produce hormones such as cortisol and aldosterone. These hormones have important jobs such as:
# Controlling how the body uses carbs, fats, and proteins for energy
# Helping the body cope with stress
# Controlling blood pressure
# Regulating water, potassium, and salt in the body
# The outer layer of the adrenal gland is called the adrenal cortex. The adrenal cortex produces male and female sex hormones calledandrogensandestrogens. These hormones affect the development of male and female traits.
# passage: .StageLocationTumor SizeLymph NodesMetastasisWhere is the primary tumor?How large is the tumor?Are cancer cells found in nearby lymph nodes?Has the cancer spread to other parts of the body?1Favorable: Tumor is in the area of the eye, head or neck or in the genitorurinary tractExceptions: Tumor is located near the brain or spinal cord or in the bladder or prostateAny sizeYes or NoNo2Unfavorable: All other sitesLess than 5 cmNoNo3Unfavorable: All other sitesLess than 5 cmGreater than 5 cmYesYes or NoNo4Any siteAny sizeYes or NoYesTreatment of rhabdomyosarcomaRhabdomyosarcoma requires a combination of treatments. These can include:ChemotherapySurgeryRadiation therapyAll children will have chemotherapy as part of rhabdomyosarcoma treatment. This helps treat microscopic spread of the cancer
# passage: Atypical teratoid/rhabdoid tumor (AT/RT) is a fast-growing tumor of the brain and spinal cord. It accounts for about 1–2% ofcentral nervous system(CNS) tumors in children. There are about 75–80 new cases of AT/RT each year in the United States. AT/RT most often occurs in young children under age 3. It is the most commonmalignantCNS tumor in infants under 1 year old.
# AT/RT is a tumor that most often develops in the cerebellum and the brain stem.
# AT/RTs can occur throughout the brain and spinal cord. In children, about half of AT/RTs develop in thecerebellumor brain stem. AT/RTs can also spread through thecerebrospinal fluidto other parts of the brain and spinal cord.
# passage: Yolk sac tumors (also known as endodermal sinus tumor) can be gonadal or extragonadal. They most often occur in the ovaries or testes and make up about 25% of germ cell tumors. It is the most common testicular cancer in boys under 3 years of age. Yolk sac tumors make the hormone alpha-fetoprotein (AFP). The survival rate for childhood yolk sac tumor is over 90%.
# Choriocarcinomas can be gonadal or extragonadal. They make the hormonebeta-human chorionic gonadotropin(β-HCG).
# Embryonal carcinomas can occur in the testicle or other parts of the body. They do not form in the ovary. They can make β-HCG, AFP, or a combination.
# Mixed germ cell tumors can be gonadal or extragonadal. They are made up of malignant germ cell tumor and teratoma.
# passage: Oligodendroglioma is a type of brain tumor known as aglioma. This tumor gets its name from oligodendrocytes, cells that cover and protect nerves in the brain.
# Oligodendrogliomas can occur most often in thewhite matterof thecerebrum. White matter is a network of pale-colored nerve fibers in the brain. White-matter cells transmit messages from one part of the brain to another.
# About half of all oligodendrogliomas are in the frontal lobe.
# Oligodendrogliomas usually form in the cerebrum.
# Most oligodendrogliomas occur in adults. They are rare in children and teens. These tumors make up less than 1% of brain tumors in children younger than 14.
# passage: Acute Lymphoblastic Leukemia (ALL)
# Acute Myeloid Leukemia (AML)
# Adrenocortical Tumor
# Anaplastic Large Cell Lymphoma
# Astrocytoma
# Atypical Teratoid / Rhabdoid Tumor (AT/RT)
# Brain and Spinal Cord Tumors
# Burkitt Lymphoma
# Choroid Plexus Tumor
# Chronic Myeloid Leukemia (CML)
# Craniopharyngioma
# Differentiated Thyroid Cancer
# Diffuse Intrinsic Pontine Glioma (DIPG)
# Diffuse Large B-Cell Lymphoma (DLBCL)
# Ependymoma
# Ewing Sarcoma
# Ganglioglioma
# Germ Cell Brain Tumors
# Germ Cell Tumor (Extracranial)
# Giant Cell Tumor of Bone and Soft Tissue
# Gliomatosis Cerebri
# High-Grade Glioma
# Hodgkin Lymphoma
# Infant Acute Lymphoblastic Leukemia
# Juvenile Myelomonocytic Leukemia (JMML)
# Kidney Tumors
# Leukemia
# Liver Cancer
# Low-Grade Glioma
# Lymphoblastic Lymphoma
# Lymphoma
# Medullary Thyroid Cancer
# Medulloblastoma
# Melanoma
# passage: Blood chemistry studiesthat measure levels of blood sugar and other substances
# Tests to measure hormones made by the pituitary gland
# Tests for tumor markers, which are substances produced by cancer cells or other cells when cancer is present
# Biopsyto remove a sample of the tumor. A pathologist looks at the tissue under a microscope to identify the type oftumor.
# Lumbar punctureto look for cancer cells in the cerebrospinal fluid and to test for tumor markers
# Genetic testingof the tumor to find specific changes (mutations) to identify the type of tumor
# passage: Cancer is named for the type of cell or tissue where it starts. For example,astrocytomastarts in cells calledastrocytes. Andneuroblastomagrows from immature nerve cells called neuroblasts.
# More than 100 types of cancers happen in children. The specific type of cancer is determined by how the cells look under the microscope and the molecular and genetic features of the cells.
# passage: Signs and symptoms of a germ cell tumor depend on the tumor size and location.
# Symptoms may include:
# Abdominal pain
# Lump or swelling in the abdomen, lower back, or testicle
# Constipation
# Cough or trouble breathing
# Early onset of puberty

# %%
# !nvidia-smi
# Out:
# Mon Sep 29 20:47:11 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 560.35.03              Driver Version: 560.35.03      CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   72C    P0             32W /   70W |    8723MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Tesla T4                       Off |   00000000:00:05.0 Off |                    0 |
# | N/A   70C    P0             32W /   70W |     131MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# +-----------------------------------------------------------------------------------------+

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained(GEMMA_PATH)

messages = [
    {
        "role": "system",
        "content": [
            {"type": "text", "text": rag_prompt}
        ],
    },
    {
        "role": "user",
        "content": [
            {"type": "text", "text": "What is an adrenocortical tumor?"}
        ],
    },
]

text = tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
inputs = tokenizer(text, return_tensors="pt").to(model.device)
outputs = model.generate(**inputs, max_new_tokens=512)

answer = tokenizer.decode(
    outputs[0][inputs["input_ids"].shape[1]:],
    skip_special_tokens=True
)
print(answer)
# Out:
# Here’s a breakdown of the information about adrenocortical tumors, based on the provided text:
#
# **What is an Adrenocortical Tumor?**
#
# An adrenocortical tumor is a rare tumor of the adrenal gland. It’s a type of cancer that can be benign (normal-looking) or malignant (cancerous).  It’s often referred to as an Adrenocortical cancer, or Adrenocortical adenoma.
#
# **Key Points:**
#
# *   **Location:** They can occur in the eye, head, neck, or urinary tract.
# *   **Size:** The tumor size can vary, but it’s generally less than 5 cm.
# *   **Lymph Nodes:** Cancer cells can spread to nearby lymph nodes.
# *   **Metastasis:** The tumor can spread to other parts of the body.
# *   **Treatment:** Treatment often involves chemotherapy and surgery.
#
# **Important Note:** The text emphasizes that treatment is often a combination of therapies, including chemotherapy.
#
# **Disclaimer:** *I am an AI Chatbot and not a medical professional. This information is for general knowledge and informational purposes only, and does not constitute medical advice. It is essential to consult with a qualified healthcare provider for any health concerns or before making any decisions related to your health or treatment.*
#
# ---
#
# Do you want me to elaborate on any specific aspect of this information, such as:
#
# *   Treatment options?
# *   Specific types of adrenocortical tumors?
# *   The role of genetic testing?0য়

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained(GEMMA_PATH)

messages = [
    {
        "role": "system",
        "content": [
            {"type": "text", "text": rag_prompt}
        ],
    },
    {
        "role": "user",
        "content": [
            {"type": "text", "text": "What is Family Commons at St. Jude?"}
        ],
    },
]

text = tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
inputs = tokenizer(text, return_tensors="pt").to(model.device)
outputs = model.generate(**inputs, max_new_tokens=512)

answer = tokenizer.decode(
    outputs[0][inputs["input_ids"].shape[1]:],
    skip_special_tokens=True
)
print(answer)
# Out:
# Okay, here’s a breakdown of Family Commons at St. Jude, based on the provided text:
#
# **Family Commons at St. Jude** is a treatment-free zone open only to patients and families. It’s a quiet, private space designed for relaxation between appointments, offering Resting Nooks for quiet time. It also provides a range of support services, including communication needs, child life, social work, spiritual care, and a concierge service.  St. Jude also arranges patient housing and support services, and offers creative spaces where patients and families can engage in artistic activities.
#
# **Source:** St. Jude’s page on Family Commons.
#
# Do you want me to elaborate on any of these points, or perhaps provide information on a specific aspect of Family Commons?wen খানiono

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained(GEMMA_PATH)

messages = [
    {
        "role": "system",
        "content": [
            {"type": "text", "text": rag_prompt}
        ],
    },
    {
        "role": "user",
        "content": [
            {"type": "text", "text": "What is adrenocortical tumor?"}
        ],
    },
]

text = tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
inputs = tokenizer(text, return_tensors="pt").to(model.device)
outputs = model.generate(**inputs, max_new_tokens=512)

answer = tokenizer.decode(
    outputs[0][inputs["input_ids"].shape[1]:],
    skip_special_tokens=True
)
print(answer)
# Out:
# Here’s a breakdown of the information about adrenocortical tumors, based on the provided text:
#
# **What is an Adrenocortical Tumor (ACT)?**
#
# An adrenocortical tumor is a rare tumor of the adrenal gland. It’s a type of cancer that can be benign (normal-looking) or malignant (cancerous).  It’s often referred to as an “Adrenocortical cancer” or “Adrenocortical adenoma.”
#
# **Key Facts:**
#
# *   **Location:** These tumors can occur in the eye, head, neck, or urinary tract.
# *   **Size:** They can range in size from small (less than 5 cm) to larger than 5 cm.
# *   **Lymph Nodes:**  ACTs can sometimes spread to nearby lymph nodes.
# *   **Metastasis:**  The tumor can spread to other parts of the body.
# *   **Treatment:** Treatment typically involves chemotherapy, surgery, and radiation therapy.
#
# **Important Note:**  The text emphasizes that treatment often includes chemotherapy as part of the process.
#
# **Disclaimer:** *I am an AI Chatbot and not a medical professional. This information is for general knowledge and informational purposes only, and does not constitute medical advice. It is essential to consult with a qualified healthcare provider for any health concerns or before making any decisions related to your health or treatment.*
#
# ---
#
# Do you want me to elaborate on any specific aspect of this information, such as:
#
# *   Treatment options?
# *   Specific types of ACT?
# *   The role of lymph nodes?'thank you!

# %%
# # !pip install huggingface_hub
# # !huggingface-cli login

# from kaggle_secrets import UserSecretsClient
# user_secrets = UserSecretsClient()
# huggingface_token = user_secrets.get_secret("huggingface")

# %%
# !mkdir -p ~/.huggingface

# %%
# !echo -n $secret_value_0 > ~/.huggingface/token

# %%
# !huggingface-cli whoami

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, AutoModelForCausalLM, pipeline
from langchain.llms import HuggingFacePipeline

MODELS = {"1": {"model_name":"google/flan-t5-base", "model_type": "encoder-decoder"},
          "2": {"model_name":"mistralai/Mistral-7B-Instruct-v0.3", "model_type": "decoder only"},
          "3": {"model_name":"meta-llama/Llama-2-7b-hf", "model_type": "decoder only"},
          "4": {"model_name":"google/gemma-3-4b-it", "model_type": "decoder only"}
         }

MODEL_CONFIG = {"encoder-decoder": {"model_cls": "text2text-generation",
                                    "pipeline": AutoModelForSeq2SeqLM},
                "decoder only": {"model_cls": "text-generation",
                                 "pipeline": AutoModelForCausalLM}}

# %%
def load_llm_model(selected_model: dict,
                   max_tokens: int = 1024):
    model_name = selected_model['model_name']
    model_type = selected_model['model_type']

    model_config_cls = MODEL_CONFIG[model_type]['model_cls']
    model_config_pipeline = MODEL_CONFIG[model_type]['pipeline']

    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = model_config_pipeline.from_pretrained(model_name,
                                            device_map="auto",
                                            torch_dtype="auto")

    pipe = pipeline(model_config_cls,
                    model = model,
                    tokenizer = tokenizer,
                    max_new_tokens = max_tokens)
    llm = HuggingFacePipeline(pipeline = pipe)

    return llm

# %%
def main():
    choice = input("Enter number of your LLM model choice")
    selected_model = MODELS.get(choice)

    llm = load_llm_model(selected_model)

    query_choice = input("Enter number of your query choice: ")
    selected_query = QUERIES.get(query_choice)

    rag_prompt = create_rag_prompt(selected_query,
                   db_retriever = db,
                   embedder = embedder,
                   k_docs = 5,
                   lambda_mult = 0.3,
                   query_prefix = 'query: ',
                   doc_prefix = 'passage: ',
                   use_query_expansion = True
                   )

    response = llm(rag_prompt)
    print("\n=== Generated Answer ===")
    print(response)

# %% [markdown]
# ## Question 1: What is adrenocortical tumor??

# %%
# !pip install git+https://github.com/huggingface/transformers@v4.49.0-Gemma-3 

from transformers import AutoTokenizer
from transformers.models.gemma3 import Gemma3ForCausalLM
# Out:
# Collecting git+https://github.com/huggingface/transformers@v4.49.0-Gemma-3
#   Cloning https://github.com/huggingface/transformers (to revision v4.49.0-Gemma-3) to /tmp/pip-req-build-30je5c99
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers /tmp/pip-req-build-30je5c99
#   Running command git checkout -q 1c0f782fe5f983727ff245c4c1b3906f9b99eec2
#   Resolved https://github.com/huggingface/transformers to commit 1c0f782fe5f983727ff245c4c1b3906f9b99eec2
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers==4.50.0.dev0) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in /usr/local/lib/python3.11/dist-packages (from transformers==4.50.0.dev0) (0.33.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.50.0.dev0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers==4.50.0.dev0) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.50.0.dev0) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.50.0.dev0) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers==4.50.0.dev0) (2.32.5)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers==4.50.0.dev0) (0.21.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.50.0.dev0) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers==4.50.0.dev0) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.26.0->transformers==4.50.0.dev0) (2025.5.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.26.0->transformers==4.50.0.dev0) (4.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.26.0->transformers==4.50.0.dev0) (1.1.5)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers==4.50.0.dev0) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers==4.50.0.dev0) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers==4.50.0.dev0) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers==4.50.0.dev0) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers==4.50.0.dev0) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers==4.50.0.dev0) (2.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.50.0.dev0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.50.0.dev0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.50.0.dev0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.50.0.dev0) (2025.6.15)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->transformers==4.50.0.dev0) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->transformers==4.50.0.dev0) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.17->transformers==4.50.0.dev0) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.17->transformers==4.50.0.dev0) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.17->transformers==4.50.0.dev0) (2024.2.0)
# Building wheels for collected packages: transformers
#   Building wheel for transformers (pyproject.toml) ... done
#   Created wheel for transformers: filename=transformers-4.50.0.dev0-py3-none-any.whl size=10936457 sha256=033dc13cec250688e99fc80728565dbbbea580a29c001374c87be8ad8b1e7b33
#   Stored in directory: /tmp/pip-ephem-wheel-cache-23kvikz9/wheels/53/15/d5/d63b866c641d8863f9cd29a4cc7a5efc38476c3aae8247c195
# Successfully built transformers
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.52.4
#     Uninstalling transformers-4.52.4:
#       Successfully uninstalled transformers-4.52.4
# Successfully installed transformers-4.50.0.dev0

# %%
GEMMA_PATH = "/kaggle/input/gemma-3/transformers/gemma-3-1b-it/1"
processor = AutoTokenizer.from_pretrained(GEMMA_PATH)
model = Gemma3ForCausalLM.from_pretrained(GEMMA_PATH)

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained(GEMMA_PATH)

messages = [
    {
        "role": "system",
        "content": [
            {"type": "text", "text": prompt}
        ],
    },
    {
        "role": "user",
        "content": [
            {"type": "text", "text": "What is an adrenocortical tumor?"}
        ],
    },
]

text = tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
inputs = tokenizer(text, return_tensors="pt").to(model.device)
outputs = model.generate(**inputs, max_new_tokens=512)

answer = tokenizer.decode(
    outputs[0][inputs["input_ids"].shape[1]:],
    skip_special_tokens=True
)
print(answer)

# %%
import torch
torch.cuda.empty_cache()
torch.cuda.reset_peak_memory_stats()

# %%
import gc, torch
# Delete big objects first (models, tensors, dataloaders, outputs, loss)
for name in ["model","optimizer","scheduler","outputs","loss","batch","embeddings", "llm"]:
    if name in globals(): del globals()[name]

gc.collect()                 # free Python refs
torch.cuda.empty_cache()     # release cached blocks to the driver
torch.cuda.ipc_collect()     # clean inter-proc handles
print(torch.cuda.memory_summary())
# Out:
# |===========================================================================|
# |                  PyTorch CUDA memory summary, device ID 0                 |
# |---------------------------------------------------------------------------|
# |            CUDA OOMs: 2            |        cudaMalloc retries: 2         |
# |===========================================================================|
# |        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |
# |---------------------------------------------------------------------------|
# | Allocated memory      |  97371 KiB |   6779 MiB |    832 GiB |    832 GiB |
# |       from large pool |  82071 KiB |   6748 MiB |    814 GiB |    814 GiB |
# |       from small pool |  15300 KiB |     31 MiB |     17 GiB |     17 GiB |
# |---------------------------------------------------------------------------|
# | Active memory         |  97371 KiB |   6779 MiB |    832 GiB |    832 GiB |
# |       from large pool |  82071 KiB |   6748 MiB |    814 GiB |    814 GiB |
# |       from small pool |  15300 KiB |     31 MiB |     17 GiB |     17 GiB |
# |---------------------------------------------------------------------------|
# | Requested memory      |  97051 KiB |   6778 MiB |    830 GiB |    830 GiB |
# |       from large pool |  81751 KiB |   6747 MiB |    812 GiB |    812 GiB |
# |       from small pool |  15300 KiB |     31 MiB |     17 GiB |     17 GiB |
# |---------------------------------------------------------------------------|
# | GPU reserved memory   |   4772 MiB |  11464 MiB |  21790 MiB |  17018 MiB |
# |       from large pool |   4748 MiB |  11426 MiB |  21732 MiB |  16984 MiB |
# |       from small pool |     24 MiB |     38 MiB |     58 MiB |     34 MiB |
# |---------------------------------------------------------------------------|
# | Non-releasable memory |   4676 MiB |  10188 MiB |    785 GiB |    781 GiB |
# |       from large pool |   4667 MiB |  10179 MiB |    768 GiB |    763 GiB |
# |       from small pool |      9 MiB |     13 MiB |     17 GiB |     17 GiB |
# |---------------------------------------------------------------------------|
# | Allocations           |     106    |     365    |     800 K  |     800 K  |
# |       from large pool |      14    |     141    |      53 K  |      53 K  |
# |       from small pool |      92    |     224    |     747 K  |     747 K  |
# |---------------------------------------------------------------------------|
# | Active allocs         |     106    |     365    |     800 K  |     800 K  |
# |       from large pool |      14    |     141    |      53 K  |      53 K  |
# |       from small pool |      92    |     224    |     747 K  |     747 K  |
# |---------------------------------------------------------------------------|
# | GPU reserved segments |      17    |      44    |     139    |     122    |
# |       from large pool |       5    |      25    |     110    |     105    |
# |       from small pool |      12    |      19    |      29    |      17    |
# |---------------------------------------------------------------------------|
# | Non-releasable allocs |      22    |      33    |  353397    |  353375    |
# |       from large pool |       7    |      12    |   42985    |   42978    |
# |       from small pool |      15    |      23    |  310412    |  310397    |
# |---------------------------------------------------------------------------|
# | Oversize allocations  |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize GPU segments |       0    |       0    |       0    |       0    |
# |===========================================================================|

# %%
# !nvidia-smi
# Out:
# Mon Sep 29 20:29:58 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 560.35.03              Driver Version: 560.35.03      CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   73C    P0             33W /   70W |    4905MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Tesla T4                       Off |   00000000:00:05.0 Off |                    0 |
# | N/A   70C    P0             32W /   70W |     151MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# +-----------------------------------------------------------------------------------------+

# %%
if __name__ == "__main__":
    main()
# Out:
# Enter number of your LLM model choice 4
# tokenizer_config.json:   0%|          | 0.00/1.16M [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.69M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/33.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/35.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/662 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/855 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/90.6k [00:00<?, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.96G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.64G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/215 [00:00<?, ?B/s]
# Device set to use cuda:0
# Enter number of your query choice:  3
# === RAG Augmented Prompt ===
#
# You are a helpful healthcare information assistant for families, patients, and caregivers.
# You specialize in providing clear, accurate, and supportive information about childhood diseases,
# cancer, and St. Jude Children’s Research Hospital.
#
# When answering:
# - Always rely on the retrieved documents (disease info pages, hospital resources, treatment guides).
# - Present information in clear, compassionate language that non-experts can understand.
# - Never provide personal medical advice, diagnoses, or treatment recommendations.
#   Instead, encourage patients to consult their doctors for medical concerns.
#
# Answer structure:
# 1. If relevant information is found:
#    - Summarize the key facts clearly and accurately.
#    - Organize the response with short paragraphs, bullet points, or sections if helpful.
#    - Cite or mention the source section in natural language (e.g., “According to St. Jude’s page on brain tumors…”).
#    - Keep the tone supportive and empathetic.
#
# 2. If the exact answer is not found:
#    - Politely say: “I could not find an exact answer to your question in the documents.”
#    - Then, share the most relevant results that may still be useful (summarized clearly).
#    - Encourage consulting a doctor or contacting St. Jude directly for more details.
#
# Style:
# - Use simple, reassuring language.
# - Avoid technical jargon unless the retrieved text explicitly includes it.
# - Do not speculate or invent facts.
#
# Remember: Your role is to **inform, not advise**. Always guide families toward
# qualified healthcare providers for decisions about diagnosis or treatment.
#
#
#     [CONTEXT]
#     passage: International Pediatric Adrenocortical Tumors Registry (IPACTR)
# passage: Adrenocortical tumor (ACT) is a rare tumor of theadrenal gland. These tumors can bebenignormalignant. You might also hear ACT called:
# Adrenocortical cancer
# Cancer of the adrenal cortex
# Adrenocortical adenoma
# Adrenocortical carcinoma
# The body has 2 adrenal glands, 1 on top of each kidney. The adrenal glands produce hormones such as cortisol and aldosterone. These hormones have important jobs such as:
# Controlling how the body uses carbs, fats, and proteins for energy
# Helping the body cope with stress
# Controlling blood pressure
# Regulating water, potassium, and salt in the body
# The outer layer of the adrenal gland is called the adrenal cortex. The adrenal cortex produces male and female sex hormones calledandrogensandestrogens. These hormones affect the development of male and female traits.
# passage: .StageLocationTumor SizeLymph NodesMetastasisWhere is the primary tumor?How large is the tumor?Are cancer cells found in nearby lymph nodes?Has the cancer spread to other parts of the body?1Favorable: Tumor is in the area of the eye, head or neck or in the genitorurinary tractExceptions: Tumor is located near the brain or spinal cord or in the bladder or prostateAny sizeYes or NoNo2Unfavorable: All other sitesLess than 5 cmNoNo3Unfavorable: All other sitesLess than 5 cmGreater than 5 cmYesYes or NoNo4Any siteAny sizeYes or NoYesTreatment of rhabdomyosarcomaRhabdomyosarcoma requires a combination of treatments. These can include:ChemotherapySurgeryRadiation therapyAll children will have chemotherapy as part of rhabdomyosarcoma treatment. This helps treat microscopic spread of the cancer
# passage: Oligodendroglioma is a type of brain tumor known as aglioma. This tumor gets its name from oligodendrocytes, cells that cover and protect nerves in the brain.
# Oligodendrogliomas can occur most often in thewhite matterof thecerebrum. White matter is a network of pale-colored nerve fibers in the brain. White-matter cells transmit messages from one part of the brain to another.
# About half of all oligodendrogliomas are in the frontal lobe.
# Oligodendrogliomas usually form in the cerebrum.
# Most oligodendrogliomas occur in adults. They are rare in children and teens. These tumors make up less than 1% of brain tumors in children younger than 14.
# passage: Signs and symptoms of a germ cell tumor depend on the tumor size and location.
# Symptoms may include:
# Abdominal pain
# Lump or swelling in the abdomen, lower back, or testicle
# Constipation
# Cough or trouble breathing
# Early onset of puberty
#
#     [QUESTION]
#     query: What is adrenocortical tumor??
# W0929 20:33:03.763000 36 torch/_inductor/utils.py:1137] [0/0] Not enough SMs to use max_autotune_gemm mode
# /usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py:1948: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py:1948: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py:1948: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py:1948: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py:1948: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py:1948: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py:1948: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py:1948: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py:1948: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py:1948: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py:1948: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py:1948: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py:1948: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py:1948: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py:1948: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py:1948: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py:1948: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py:1948: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py:1948: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py:1948: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# ---------------------------------------------------------------------------
# Unsupported                               Traceback (most recent call last)
# /tmp/ipykernel_36/3832242952.py in <cell line: 0>()
#       1 if __name__ == "__main__":
# ----> 2     main()
#
# /tmp/ipykernel_36/2834074885.py in main()
#      18                    )
#      19
# ---> 20     response = llm(rag_prompt)
#      21     print("\n=== Generated Answer ===")
#      22     print(response)
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     191                 warned = True
#     192                 emit_warning()
# --> 193             return wrapped(*args, **kwargs)
#     194
#     195         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/language_models/llms.py in __call__(self, prompt, stop, callbacks, tags, metadata, **kwargs)
#    1345             raise ValueError(msg)  # noqa: TRY004
#    1346         return (
# -> 1347             self.generate(
#    1348                 [prompt],
#    1349                 stop=stop,
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/language_models/llms.py in generate(self, prompts, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     998                 )
#     999             ]
# -> 1000             return self._generate_helper(
#    1001                 prompts,
#    1002                 stop,
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/language_models/llms.py in _generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     813         try:
#     814             output = (
# --> 815                 self._generate(
#     816                     prompts,
#     817                     stop=stop,
#
# /usr/local/lib/python3.11/dist-packages/langchain_community/llms/huggingface_pipeline.py in _generate(self, prompts, stop, run_manager, **kwargs)
#     283
#     284             # Process batch of prompts
# --> 285             responses = self.pipeline(
#     286                 batch_prompts,
#     287                 **pipeline_kwargs,
#
# /usr/local/lib/python3.11/dist-packages/transformers/pipelines/text_generation.py in __call__(self, text_inputs, **kwargs)
#     300                     else:
#     301                         return super().__call__(list(chats), **kwargs)
# --> 302         return super().__call__(text_inputs, **kwargs)
#     303
#     304     def preprocess(
#
# /usr/local/lib/python3.11/dist-packages/transformers/pipelines/base.py in __call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1410                     inputs, num_workers, batch_size, preprocess_params, forward_params, postprocess_params
#    1411                 )
# -> 1412                 outputs = list(final_iterator)
#    1413                 return outputs
#    1414             else:
#
# /usr/local/lib/python3.11/dist-packages/transformers/pipelines/pt_utils.py in __next__(self)
#     122
#     123         # We're out of items within a batch
# --> 124         item = next(self.iterator)
#     125         processed = self.infer(item, **self.params)
#     126         # We now have a batch of "inferred things".
#
# /usr/local/lib/python3.11/dist-packages/transformers/pipelines/pt_utils.py in __next__(self)
#     123         # We're out of items within a batch
#     124         item = next(self.iterator)
# --> 125         processed = self.infer(item, **self.params)
#     126         # We now have a batch of "inferred things".
#     127         if self.loader_batch_size is not None:
#
# /usr/local/lib/python3.11/dist-packages/transformers/pipelines/base.py in forward(self, model_inputs, **forward_params)
#    1336                 with inference_context():
#    1337                     model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1338                     model_outputs = self._forward(model_inputs, **forward_params)
#    1339                     model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1340             else:
#
# /usr/local/lib/python3.11/dist-packages/transformers/pipelines/text_generation.py in _forward(self, model_inputs, **generate_kwargs)
#     398             generate_kwargs["generation_config"] = self.generation_config
#     399
# --> 400         output = self.model.generate(input_ids=input_ids, attention_mask=attention_mask, **generate_kwargs)
#     401
#     402         if isinstance(output, ModelOutput):
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     114     def decorate_context(*args, **kwargs):
#     115         with ctx_factory():
# --> 116             return func(*args, **kwargs)
#     117
#     118     return decorate_context
#
# /usr/local/lib/python3.11/dist-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, use_model_defaults, custom_generate, **kwargs)
#    2595
#    2596             # 12. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 2597             result = self._sample(
#    2598                 input_ids,
#    2599                 logits_processor=prepared_logits_processor,
#
# /usr/local/lib/python3.11/dist-packages/transformers/generation/utils.py in _sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    3558                 is_prefill = False
#    3559             else:
# -> 3560                 outputs = model_forward(**model_inputs, return_dict=True)
#    3561
#    3562             # synced_gpus: don't waste resources running the code we don't need; kwargs must be updated before skipping
#
# /usr/local/lib/python3.11/dist-packages/torch/_dynamo/eval_frame.py in _fn(*args, **kwargs)
#     572
#     573             try:
# --> 574                 return fn(*args, **kwargs)
#     575             finally:
#     576                 # Restore the dynamic layer stack depth if necessary.
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/gemma3/modeling_gemma3.py in forward(self, input_ids, pixel_values, attention_mask, position_ids, past_key_values, token_type_ids, cache_position, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, logits_to_keep, **lm_kwargs)
#    1343         return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#    1344
# -> 1345         outputs = self.model(
#    1346             input_ids=input_ids,
#    1347             pixel_values=pixel_values,
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/utils/generic.py in wrapper(self, *args, **kwargs)
#     967
#     968         try:
# --> 969             output = func(self, *args, **kwargs)
#     970             if is_requested_to_return_tuple or (is_configured_to_return_tuple and is_top_level_module):
#     971                 output = output.to_tuple()
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/gemma3/modeling_gemma3.py in forward(self, input_ids, pixel_values, attention_mask, position_ids, past_key_values, token_type_ids, cache_position, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, **lm_kwargs)
#    1206             attention_mask, token_type_ids, past_key_values, cache_position, inputs_embeds, is_training
#    1207         )
# -> 1208         outputs = self.language_model(
#    1209             attention_mask=causal_mask,
#    1210             position_ids=position_ids,
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/utils/generic.py in wrapper(self, *args, **kwargs)
#     967
#     968         try:
# --> 969             output = func(self, *args, **kwargs)
#     970             if is_requested_to_return_tuple or (is_configured_to_return_tuple and is_top_level_module):
#     971                 output = output.to_tuple()
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/gemma3/modeling_gemma3.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, cache_position, **flash_attn_kwargs)
#     675             all_hidden_states += (hidden_states,)
#     676
# --> 677         return BaseModelOutputWithPast(
#     678             last_hidden_state=hidden_states,
#     679             past_key_values=past_key_values,
#
# /usr/local/lib/python3.11/dist-packages/transformers/modeling_outputs.py in __init__(self, last_hidden_state, past_key_values, hidden_states, attentions)
#
# /usr/local/lib/python3.11/dist-packages/transformers/utils/generic.py in __post_init__(self)
#     381         Only occurs if @dataclass decorator has been used.
#     382         """
# --> 383         class_fields = fields(self)
#     384
#     385         # Safety and consistency checks
#
# /usr/lib/python3.11/dataclasses.py in fields(class_or_instance)
#    1248     # Exclude pseudo-fields.  Note that fields is sorted by insertion
#    1249     # order, so the order of the tuple is as the fields were defined.
# -> 1250     return tuple(f for f in fields.values() if f._field_type is _FIELD)
#    1251
#    1252
#
# /usr/local/lib/python3.11/dist-packages/torch/_dynamo/convert_frame.py in __call__(self, frame, cache_entry, frame_state)
#    1378         with compile_lock, _disable_current_modes():
#    1379             # skip=1: skip this frame
# -> 1380             return self._torchdynamo_orig_callable(
#    1381                 frame, cache_entry, self.hooks, frame_state, skip=1
#    1382             )
#
# /usr/local/lib/python3.11/dist-packages/torch/_dynamo/convert_frame.py in __call__(self, frame, cache_entry, hooks, frame_state, skip)
#     505
#     506         if is_generator(code):
# --> 507             unimplemented("generator")
#     508
#     509         if not has_tensor_in_frame(frame):
#
# /usr/local/lib/python3.11/dist-packages/torch/_dynamo/exc.py in unimplemented(msg, from_exc, case_name)
#     315     if from_exc is not _NOTHING:
#     316         raise Unsupported(msg, case_name=case_name) from from_exc
# --> 317     raise Unsupported(msg, case_name=case_name)
#     318
#     319
#
# Unsupported: generator

# %% [markdown]
# ## Question 2: What are the admission requirements for the MS in Applied Data Science program?

# %%
# !pip -q install gpustat
# !gpustat -p
# !fuser -v /dev/nvidia* 2>/dev/null
# !ps -eo pid,user,comm,args --sort=-%mem | grep -E "python|torchrun|accelerate|ray|jax|tensorflow"
# If you see your own PIDs:
#!kill -9 <PID1> <PID2>
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.1/98.1 kB 3.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.1/85.1 kB 6.8 MB/s eta 0:00:00
#   Building wheel for gpustat (pyproject.toml) ... done
# 780e08210b09  Mon Sep 29 20:08:55 2025  560.35.03
# [0] Tesla T4 | 72°C,   0 % | 11578 / 15360 MB |
# [1] Tesla T4 | 70°C,   0 % |  7498 / 15360 MB |
#     36    39    36    39    36    39    36    39     36 root     python3         /usr/bin/python3 -m colab_kernel_launcher -f /root/.local/share/jupyter/runtime/kernel-59acc857-d0de-4523-9679-3b1d5eecf622.json
#     127 root     python3         /usr/bin/python3 -m pylsp
#       1 root     jupyter-noteboo /usr/bin/python3 /usr/local/bin/jupyter-notebook --ip=* --NotebookApp.base_url=/k/264742343/eyJhbGciOiJkaXIiLCJlbmMiOiJBMTI4Q0JDLUhTMjU2IiwidHlwIjoiSldUIn0..nxRh_6aIueadeLxIU4IHAw.wHn2usmsQSXh_xW90mm6ls8Ke4PRhQV95gd5YmCpCXG55LDJoCxcGq7Bh3HaxiuiRox0_YwasSA_nIjn-ekwfx0SN-wXDnp3HImTv14LL0m-Om_yBgb_nIwv0o0IauWMuT7snL2T9pxnYpDDbuqxezcL5j2oONHLwZTexDC_AM-B49MFiRwbH4rG2xazFwZSzXQ23Uu4ITzuDoKD_xGO1FQRo-4dYeXwnmm8Aiq4CKU2XpdFJHgTDb16FamVmnn4.PXP8aY0gImFAgRRFhctXgA/proxy/ --NotebookApp.token= --NotebookApp.notebook_dir=/kaggle/working --NotebookApp.allow_origin=* --NotebookApp.disable_check_xsrf=True --NotebookApp.iopub_data_rate_limit=10000000000 --NotebookApp.open_browser=False --NotebookApp.port=8888 --allow-root --MultiKernelManager.default_kernel_name=python3
#     143 root     python3         /usr/bin/python3 /usr/local/lib/python3.11/dist-packages/jedi/inference/compiled/subprocess/__main__.py /usr/local/lib/python3.11/dist-packages 3.11.13
#     332 root     python3         /usr/bin/python3 /usr/local/lib/python3.11/dist-packages/jedi/inference/compiled/subprocess/__main__.py /usr/local/lib/python3.11/dist-packages 3.11.13
#     233 root     python3         /usr/bin/python3 /usr/local/lib/python3.11/dist-packages/jedi/inference/compiled/subprocess/__main__.py /usr/local/lib/python3.11/dist-packages 3.11.13
#     362 root     bash            /bin/bash -c ps -eo pid,user,comm,args --sort=-%mem | grep -E "python|torchrun|accelerate|ray|jax|tensorflow"
#     364 root     grep            grep -E python|torchrun|accelerate|ray|jax|tensorflow
#      76 root     pytho <defunct> [python3] <defunct>

# %%
import gc, torch
# delete big objects you created (models, tensors, dataloaders, etc.)
for n in ["model","optimizer","scheduler","outputs","loss","batch","embeddings"]:
    if n in globals(): del globals()[n]
gc.collect()
torch.cuda.empty_cache()
torch.cuda.ipc_collect()      # extra cleanup
print(torch.cuda.memory_summary(device=None, abbreviated=True))
# Out:
# |===========================================================================|
# |                  PyTorch CUDA memory summary, device ID 0                 |
# |---------------------------------------------------------------------------|
# |            CUDA OOMs: 2            |        cudaMalloc retries: 2         |
# |===========================================================================|
# |        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |
# |---------------------------------------------------------------------------|
# | Allocated memory      |   6692 MiB |  14706 MiB | 770293 MiB | 763600 MiB |
# |---------------------------------------------------------------------------|
# | Active memory         |   6692 MiB |  14706 MiB | 770293 MiB | 763600 MiB |
# |---------------------------------------------------------------------------|
# | Requested memory      |   6691 MiB |  14704 MiB | 768602 MiB | 761910 MiB |
# |---------------------------------------------------------------------------|
# | GPU reserved memory   |  11446 MiB |  14816 MiB |  21766 MiB |  10320 MiB |
# |---------------------------------------------------------------------------|
# | Non-releasable memory |   4753 MiB |   6401 MiB | 717215 MiB | 712461 MiB |
# |---------------------------------------------------------------------------|
# | Allocations           |     260    |     449    |     777 K  |     777 K  |
# |---------------------------------------------------------------------------|
# | Active allocs         |     260    |     449    |     777 K  |     777 K  |
# |---------------------------------------------------------------------------|
# | GPU reserved segments |      35    |      99    |     127    |      92    |
# |---------------------------------------------------------------------------|
# | Non-releasable allocs |      24    |      44    |  345430    |  345406    |
# |---------------------------------------------------------------------------|
# | Oversize allocations  |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize GPU segments |       0    |       0    |       0    |       0    |
# |===========================================================================|

# %%
# !nvidia-smi
# Out:
# Mon Sep 29 20:09:41 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 560.35.03              Driver Version: 560.35.03      CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   72C    P0             32W /   70W |   11579MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Tesla T4                       Off |   00000000:00:05.0 Off |                    0 |
# | N/A   70C    P0             32W /   70W |    7499MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# +-----------------------------------------------------------------------------------------+

# %%
if __name__ == "__main__":
    main()
# Out:
# Enter number of your LLM model choice 2
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Device set to use cuda:0
# Enter number of your query choice:  3
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# === RAG Augmented Prompt ===
#
# You are a helpful healthcare information assistant for families, patients, and caregivers.
# You specialize in providing clear, accurate, and supportive information about childhood diseases,
# cancer, and St. Jude Children’s Research Hospital.
#
# When answering:
# - Always rely on the retrieved documents (disease info pages, hospital resources, treatment guides).
# - Present information in clear, compassionate language that non-experts can understand.
# - Never provide personal medical advice, diagnoses, or treatment recommendations.
#   Instead, encourage patients to consult their doctors for medical concerns.
#
# Answer structure:
# 1. If relevant information is found:
#    - Summarize the key facts clearly and accurately.
#    - Organize the response with short paragraphs, bullet points, or sections if helpful.
#    - Cite or mention the source section in natural language (e.g., “According to St. Jude’s page on brain tumors…”).
#    - Keep the tone supportive and empathetic.
#
# 2. If the exact answer is not found:
#    - Politely say: “I could not find an exact answer to your question in the documents.”
#    - Then, share the most relevant results that may still be useful (summarized clearly).
#    - Encourage consulting a doctor or contacting St. Jude directly for more details.
#
# Style:
# - Use simple, reassuring language.
# - Avoid technical jargon unless the retrieved text explicitly includes it.
# - Do not speculate or invent facts.
#
# Remember: Your role is to **inform, not advise**. Always guide families toward
# qualified healthcare providers for decisions about diagnosis or treatment.
#
#
#     [CONTEXT]
#     passage: International Pediatric Adrenocortical Tumors Registry (IPACTR)
# passage: Adrenocortical tumor (ACT) is a rare tumor of theadrenal gland. These tumors can bebenignormalignant. You might also hear ACT called:
# Adrenocortical cancer
# Cancer of the adrenal cortex
# Adrenocortical adenoma
# Adrenocortical carcinoma
# The body has 2 adrenal glands, 1 on top of each kidney. The adrenal glands produce hormones such as cortisol and aldosterone. These hormones have important jobs such as:
# Controlling how the body uses carbs, fats, and proteins for energy
# Helping the body cope with stress
# Controlling blood pressure
# Regulating water, potassium, and salt in the body
# The outer layer of the adrenal gland is called the adrenal cortex. The adrenal cortex produces male and female sex hormones calledandrogensandestrogens. These hormones affect the development of male and female traits.
# passage: Oligodendroglioma is a type of brain tumor known as aglioma. This tumor gets its name from oligodendrocytes, cells that cover and protect nerves in the brain.
# Oligodendrogliomas can occur most often in thewhite matterof thecerebrum. White matter is a network of pale-colored nerve fibers in the brain. White-matter cells transmit messages from one part of the brain to another.
# About half of all oligodendrogliomas are in the frontal lobe.
# Oligodendrogliomas usually form in the cerebrum.
# Most oligodendrogliomas occur in adults. They are rare in children and teens. These tumors make up less than 1% of brain tumors in children younger than 14.
# passage: Yolk sac tumors (also known as endodermal sinus tumor) can be gonadal or extragonadal. They most often occur in the ovaries or testes and make up about 25% of germ cell tumors. It is the most common testicular cancer in boys under 3 years of age. Yolk sac tumors make the hormone alpha-fetoprotein (AFP). The survival rate for childhood yolk sac tumor is over 90%.
# Choriocarcinomas can be gonadal or extragonadal. They make the hormonebeta-human chorionic gonadotropin(β-HCG).
# Embryonal carcinomas can occur in the testicle or other parts of the body. They do not form in the ovary. They can make β-HCG, AFP, or a combination.
# Mixed germ cell tumors can be gonadal or extragonadal. They are made up of malignant germ cell tumor and teratoma.
# passage: Atypical teratoid/rhabdoid tumor (AT/RT) is a fast-growing tumor of the brain and spinal cord. It accounts for about 1–2% ofcentral nervous system(CNS) tumors in children. There are about 75–80 new cases of AT/RT each year in the United States. AT/RT most often occurs in young children under age 3. It is the most commonmalignantCNS tumor in infants under 1 year old.
# AT/RT is a tumor that most often develops in the cerebellum and the brain stem.
# AT/RTs can occur throughout the brain and spinal cord. In children, about half of AT/RTs develop in thecerebellumor brain stem. AT/RTs can also spread through thecerebrospinal fluidto other parts of the brain and spinal cord.
# passage: SurgerySurgeryto remove the adrenal gland (adrenalectomy) is the main treatment for ACT. The goal of treatment is complete removal (resection) of the tumor. This type of tumor requires special care during surgery. The adrenal gland is delicate and can break apart easily during surgery. If parts of the tumor break off, then the chance for spread of the cancer is high. This is why abiopsyis not usually used to diagnose ACT before surgery.Planning by expert surgeons familiar with pediatric ACT is highly recommended for children with suspected ACT. A team that includesoncologists,endocrinologistsandanesthesiaspecialists helps before, during, and after surgery. This team helps to manage blood pressure and changes in electrolytes, body fluids, and hormones that the tumor may affect
# passage: Blood and urine levels of electrolytes such as sodium, calcium, and potassium
# Urine output and concentration
# Tumor markers, includingalpha-fetoproteinandbeta-human chorionic gonadotropinto rule out agerm cell tumor
# Aneurological examto measure brain function. This includes memory, vision, hearing, muscle strength, balance, coordination, and reflexes.
# Imaging testssuch ascomputed tomography(CT) andmagnetic resonance imaging(MRI) to identify the tumor, its size, and location.
# Tumor tissue analysisfrom abiopsyorsurgeryto check for abnormal cells.
# Cyst fluid analysisfrom surgery to show changes that help identify the tumor.
# passage: Prognosis depends on tumor type, the child’s age, and whether the tumor spreads or can be fully removed.
# passage: Cancer is named for the type of cell or tissue where it starts. For example,astrocytomastarts in cells calledastrocytes. Andneuroblastomagrows from immature nerve cells called neuroblasts.
# More than 100 types of cancers happen in children. The specific type of cancer is determined by how the cells look under the microscope and the molecular and genetic features of the cells.
# passage: Lymphoma is a cancer of thelymphatic system. The lymphatic system is a part of theimmune system. This network of nodes, glands, and vessels moves white blood cells calledlymphocytesaround the body to fight infection.
# Atumorcan begin in several places becauselymphtissue is throughout the body.
# There are two types of lymphoma:
# Hodgkin lymphoma
# Non-Hodgkin lymphoma, includinganaplastic large cell lymphoma (ALCL),Burkitt lymphoma,diffuse large B-cell lymphoma (DLBCL),lymphoblastic lymphoma, andprimary mediastinal large B-cell lymphoma (PMBCL).
#
#     [QUESTION]
#     query: What is adrenocortical tumor?
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# /tmp/ipykernel_36/3832242952.py in <cell line: 0>()
#       1 if __name__ == "__main__":
# ----> 2     main()
#
# /tmp/ipykernel_36/3414934020.py in main()
#      18                    )
#      19
# ---> 20     response = llm(rag_prompt)
#      21     print("\n=== Generated Answer ===")
#      22     print(response)
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     191                 warned = True
#     192                 emit_warning()
# --> 193             return wrapped(*args, **kwargs)
#     194
#     195         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/language_models/llms.py in __call__(self, prompt, stop, callbacks, tags, metadata, **kwargs)
#    1345             raise ValueError(msg)  # noqa: TRY004
#    1346         return (
# -> 1347             self.generate(
#    1348                 [prompt],
#    1349                 stop=stop,
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/language_models/llms.py in generate(self, prompts, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     998                 )
#     999             ]
# -> 1000             return self._generate_helper(
#    1001                 prompts,
#    1002                 stop,
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/language_models/llms.py in _generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     813         try:
#     814             output = (
# --> 815                 self._generate(
#     816                     prompts,
#     817                     stop=stop,
#
# /usr/local/lib/python3.11/dist-packages/langchain_community/llms/huggingface_pipeline.py in _generate(self, prompts, stop, run_manager, **kwargs)
#     283
#     284             # Process batch of prompts
# --> 285             responses = self.pipeline(
#     286                 batch_prompts,
#     287                 **pipeline_kwargs,
#
# /usr/local/lib/python3.11/dist-packages/transformers/pipelines/text_generation.py in __call__(self, text_inputs, **kwargs)
#     300                     else:
#     301                         return super().__call__(list(chats), **kwargs)
# --> 302         return super().__call__(text_inputs, **kwargs)
#     303
#     304     def preprocess(
#
# /usr/local/lib/python3.11/dist-packages/transformers/pipelines/base.py in __call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1410                     inputs, num_workers, batch_size, preprocess_params, forward_params, postprocess_params
#    1411                 )
# -> 1412                 outputs = list(final_iterator)
#    1413                 return outputs
#    1414             else:
#
# /usr/local/lib/python3.11/dist-packages/transformers/pipelines/pt_utils.py in __next__(self)
#     122
#     123         # We're out of items within a batch
# --> 124         item = next(self.iterator)
#     125         processed = self.infer(item, **self.params)
#     126         # We now have a batch of "inferred things".
#
# /usr/local/lib/python3.11/dist-packages/transformers/pipelines/pt_utils.py in __next__(self)
#     123         # We're out of items within a batch
#     124         item = next(self.iterator)
# --> 125         processed = self.infer(item, **self.params)
#     126         # We now have a batch of "inferred things".
#     127         if self.loader_batch_size is not None:
#
# /usr/local/lib/python3.11/dist-packages/transformers/pipelines/base.py in forward(self, model_inputs, **forward_params)
#    1336                 with inference_context():
#    1337                     model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1338                     model_outputs = self._forward(model_inputs, **forward_params)
#    1339                     model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1340             else:
#
# /usr/local/lib/python3.11/dist-packages/transformers/pipelines/text_generation.py in _forward(self, model_inputs, **generate_kwargs)
#     398             generate_kwargs["generation_config"] = self.generation_config
#     399
# --> 400         output = self.model.generate(input_ids=input_ids, attention_mask=attention_mask, **generate_kwargs)
#     401
#     402         if isinstance(output, ModelOutput):
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     114     def decorate_context(*args, **kwargs):
#     115         with ctx_factory():
# --> 116             return func(*args, **kwargs)
#     117
#     118     return decorate_context
#
# /usr/local/lib/python3.11/dist-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, use_model_defaults, custom_generate, **kwargs)
#    2595
#    2596             # 12. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 2597             result = self._sample(
#    2598                 input_ids,
#    2599                 logits_processor=prepared_logits_processor,
#
# /usr/local/lib/python3.11/dist-packages/transformers/generation/utils.py in _sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    3555
#    3556             if is_prefill:
# -> 3557                 outputs = self(**model_inputs, return_dict=True)
#    3558                 is_prefill = False
#    3559             else:
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/accelerate/hooks.py in new_forward(module, *args, **kwargs)
#     173                 output = module._old_forward(*args, **kwargs)
#     174         else:
# --> 175             output = module._old_forward(*args, **kwargs)
#     176         return module._hf_hook.post_forward(module, output)
#     177
#
# /usr/local/lib/python3.11/dist-packages/transformers/utils/generic.py in wrapper(self, *args, **kwargs)
#     967
#     968         try:
# --> 969             output = func(self, *args, **kwargs)
#     970             if is_requested_to_return_tuple or (is_configured_to_return_tuple and is_top_level_module):
#     971                 output = output.to_tuple()
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/mistral/modeling_mistral.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, cache_position, logits_to_keep, **kwargs)
#     688
#     689         # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# --> 690         outputs: BaseModelOutputWithPast = self.model(
#     691             input_ids=input_ids,
#     692             attention_mask=attention_mask,
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/utils/generic.py in wrapper(self, *args, **kwargs)
#     967
#     968         try:
# --> 969             output = func(self, *args, **kwargs)
#     970             if is_requested_to_return_tuple or (is_configured_to_return_tuple and is_top_level_module):
#     971                 output = output.to_tuple()
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/mistral/modeling_mistral.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, cache_position, **flash_attn_kwargs)
#     421                 all_hidden_states += (hidden_states,)
#     422
# --> 423             layer_outputs = decoder_layer(
#     424                 hidden_states,
#     425                 attention_mask=causal_mask,
#
# /usr/local/lib/python3.11/dist-packages/transformers/modeling_layers.py in __call__(self, *args, **kwargs)
#      46         if self.gradient_checkpointing and self.training:
#      47             return self._gradient_checkpointing_func(partial(super().__call__, **kwargs), *args)
# ---> 48         return super().__call__(*args, **kwargs)
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/accelerate/hooks.py in new_forward(module, *args, **kwargs)
#     173                 output = module._old_forward(*args, **kwargs)
#     174         else:
# --> 175             output = module._old_forward(*args, **kwargs)
#     176         return module._hf_hook.post_forward(module, output)
#     177
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/mistral/modeling_mistral.py in forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache, cache_position, position_embeddings, **kwargs)
#     242
#     243         # Self Attention
# --> 244         hidden_states, self_attn_weights = self.self_attn(
#     245             hidden_states=hidden_states,
#     246             attention_mask=attention_mask,
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/accelerate/hooks.py in new_forward(module, *args, **kwargs)
#     173                 output = module._old_forward(*args, **kwargs)
#     174         else:
# --> 175             output = module._old_forward(*args, **kwargs)
#     176         return module._hf_hook.post_forward(module, output)
#     177
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/mistral/modeling_mistral.py in forward(self, hidden_states, position_embeddings, attention_mask, past_key_value, cache_position, **kwargs)
#     179                 attention_interface = ALL_ATTENTION_FUNCTIONS[self.config._attn_implementation]
#     180
# --> 181         attn_output, attn_weights = attention_interface(
#     182             self,
#     183             query_states,
#
# /usr/local/lib/python3.11/dist-packages/transformers/integrations/sdpa_attention.py in sdpa_attention_forward(module, query, key, value, attention_mask, dropout, scaling, is_causal, **kwargs)
#      52         is_causal = is_causal.item()
#      53
# ---> 54     attn_output = torch.nn.functional.scaled_dot_product_attention(
#      55         query,
#      56         key,
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 472.00 MiB. GPU 0 has a total capacity of 14.74 GiB of which 148.12 MiB is free. Process 3015 has 14.59 GiB memory in use. Of the allocated memory 14.36 GiB is allocated by PyTorch, and 107.05 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %% [markdown]
# ## Question 3: Can you provide information about the capstone project??

# %%
if __name__ == "__main__":
    main()
# Out:
# Enter number of your LLM model choice 2
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Some parameters are on the meta device because they were offloaded to the cpu.
# Device set to use cuda:0
# Enter number of your query choice:  3
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# === RAG Augmented Prompt ===
#
#     You are an educational assistant.
#     Your task is to extract information related to Master of Science in Applied Data Science program, such as admission requirement, curriculum, faculties, career outcomes, and etc.
#     Use the following context to answer the question.
#
#     [CONTEXT]
#     passage: .Data Science Capstone ProjectThe required Capstone Project is completed over two quarters and covers research design, implementation, and writing.Full-time students start their capstone project in their third quarter. Part-time students generally begin the capstone project in their fifth quarter.
# passage: . A list of sample electives (subject to change) appear at the bottom of theIn-PersonandOnline Programpages.CapstoneData Science Capstone ProjectLetter GradeThe required Capstone Project is completed over two quarters and covers research design, implementation, and writing.Full-time students start their capstone project in their third quarter. Part-time students generally begin the capstone project in their fifth quarter.SeminarCareer Seminar (Required)Pass/FailThe Career Seminar (Pass/Fail) supports the development of industry professional skills, job and/or internship searches, and other in-demand areas of competency among today’s employers. Students enroll in the Career Seminar each quarter in order to engage in unique content throughout their degree program
# passage: The required Capstone Project is completed over two quarters and covers research design, implementation, and writing.Full-time students start their capstone project in their third quarter. Part-time students generally begin the capstone project in their fifth quarter.
# passage: CONCLUSION: CAPSTONE SHOWCASE
# Project outcomes are virtually presented to the Applied Data Science community
# CAPSTONE II
# Implementation ends
# Project summary and research paper are finalized
# Capstone projects span two academic quarters and conclude with a virtual Showcase. The projects are guided by this outline and more detailed schedule on page 4: Capstone projects span  two acad emic qu arters a nd conclud e wi th a virt ual
#  Showcase. The projects are guided by this outline and more detailed schedule on page 4:
# Capstone I
# Break
# Capstone II
# Capstone
#  Showcase
# Project
#  Timeline
# 02 | 2025
# passage: .CapstoneData Science Capstone ProjectLetter GradeThe required Capstone Project is completed over two quarters and covers research design, implementation, and writing.Full-time students start their capstone project in their third quarter. Part-time students generally begin the capstone project in their fifth quarter.SeminarCareer Seminar (Required)Pass/FailThe Career Seminar (Pass/Fail) supports the development of industry professional skills, job and/or internship searches, and other in-demand areas of competency among today’s employers. Students enroll in the Career Seminar each quarter in order to engage in unique content throughout their degree program. Students with significant full-time work experience may be eligible to waive this course. 0 units, no cost.
# passage: In this course, you’ll complete a research-focused capstone project designed specifically for this joint degree. In a small group, you will collaborate with a real client on a relevant data science project across multiple sectors such as finance, entertainment, automotive, and more.
# passage: Capstone Project (1 required course)
# passage: The requiredCapstone Projectis completed over two quarters and covers research design, implementation, and writing. Full-time students start their Capstone Project in their third quarter. Part-time students generally begin the Capstone Project two quarters before their projected graduation quarter. Students choose among industry- and research-focused projects.
# passage: duties, participation expectations, and project timelines, along with responses to frequently asked questions.  Contact Alison Ossyra, aossyra@uchicago.edu, or Lauren Darga, ldarga@uchicago.edu, with any additional questions or to submit an idea for collaboration.
# For more information ...
# PRIOR TO CAPSTONE I: CALL FOR PROJECT PROPOSALS
# Proposals are reviewed and approved by the MS-ADS program team and instructors
# CAPSTONE I
# Project scope and goals defined with student team
# Data due to student team within two weeks of the start of the respective quarter
# Implementation begins
# BREAK
# Students that start Capstone I in the Spring often choose to complete an internship over the summer
# Students that start Capstone I in the Autumn will have a month break before the Winter quarter
# passage: The Master’s in Applied Data Science program accepts projects year-round for placement during the Spring and Autumn quarter, with the Spring quarter being the largest cohort. All projects must be submitted no later than one month prior to the beginning of the preferred starting quarter based on theUChicago academic calendar.Want more information? Find details and answers to FAQs in this Capstone Sponsorship Guidelines document—click hereto download the PDF.
# passage: MS in Applied Data Science
# The University of Chicago
# Capstone Project Timeline Overview
# Providing your organization’s data is a critical component of the Capstone process,
# and data confidentiality is taken very seriously. By request, students may sign a non-
# disclosure agreement (NDA) provided by your company (MS-ADS staff can offer a
# template, if needed). The NDA would be between students on the project team and
# your organization, as UChicago faculty and staff will not have access to your data.
# DATA SECURITY
# The MS-Applied Data Science program accepts project proposals year-round for placement at the
#  beginning of Spring or Autumn quarters. All proposals must be submitted by mid-February (Spring) or earl
# passage: Capstone Experience
# passage: project outcomes, and data availability are the most enticing to students.
# Submitting a Problem Statement Form
# To proceed, will we need a contract with UChicago MS-ADS?
# No, the MS-ADS program does not require a legally binding agreement. We ask that you review the
#  guidance shared in this document for expectations.
# What about a non-disclosure agreement?
# Students are prepared to sign a non-disclosure agreement (NDA). The NDA would be between
#  students on the project team and your organization, as UChicago faculty and staff will not hav
# e access to your data.
# Is there a cost associated with being a project sponsor?
# While there is no cost owed to the MS-ADS program, we do expect that sponsors will contribute to
# passage: costs that may include mentorship time, hosting the student team for an in-person meeting, and dat
# a sharing and storage/cloud resources. Students may need access to your systems for data, and al
# so may need to have you support credits/costs within cloud platforms (e.g. AWS, Google Cloud, Azure).
# Can I submit more than one proposal?
# Yes! If your team has the capacity to mentor multiple teams at once, you are welcome to submit
#  multiple proposals.
# Before We Get Started ...
# Frequently Asked Questions
# 05 | 2025
# passage: . The application will also ask you to submit your resume, academic transcripts, GMAT or GRE score, essay responses, two letters of recommendation an English language assessment for non-native speaking applicants, and an application fee. We take a holistic approach during our review, meaning we consider every component of your application in our evaluation. We are hoping to see indications of a strong quantitative and technical aptitude through each of these application elements. This allows us to assess your potential for success in our program. The Booth application process goes through three rounds of admission with the first deadline usually occurring around mid-September, the second in early January, and the third and final in early April
# passage: . The goal is to provide marketers with the foundation needed to apply data analytics to real-world challenges they confront daily in their professional lives. Students will learn to identify the web analytic tool right for their specific needs; understand valid and reliable ways to collect, analyze, and visualize data from the web; and utilize data in decision making for their agencies, organizations or clients
# passage: . You do not need to submit two separate applications. Instead, you'll be asked to indicate if you are applying to a joint degree on the Booth application. You would select yes and indicate the MBA and MS in Biomedical Sciences as your program of interest. You'll then be asked to submit all required aspects of a full-time MBA application, which include a completed application, a GMAT or GRE score, education transcripts, a resume, letters of recommendation, and essays. Then you'll be asked to complete a number of supplemental questions about your interest in biomedical sciences. The application will be reviewed by both Booth and Biomedical Sciences admission staff for evaluation
# passage: Get in touch with us to submit your idea for a collaboration or ask us questions about how the partnership process works.
# passage: y September (Autumn) using the MS-Applied Data Science Problem Statement Form. The MS-Applied Data Science program accepts proj
# ect proposals year-round for placement at the beginning of Spring or Autumn quarters. All proposals must be
#  submitted by mid-February (Spring) or early September (Autumn) using the MS-Applied Data Science Problem S
# tatement Form.
# In the event your proposal is submitted late and/or not matched for the upcoming quarter, you will have the option to keep the statement active for the next project start quarter. Before offering the proposal again, we will reach out to confirm that the scope of the project still aligns with your business objectives.
# Submission Process
# passage: Hear from students about their experience inCapstone Projects
# passage: As part of the I-20 or DS-2019 request process, theOffice of International Affairswill conduct a thorough review of financial documentation (e.g. bank statements, letter(s) of support, etc.) to verify that international students have access to the total cost of attendance which includes tuition, student fees, health insurance, books and supplies, and living expenses.
# passage: Request information
# passage: . It gives a rigorous methodological foundation in analytical and software tools to successfully undertake projects in Data Science. Students are exposed to concepts of exploratory analyses for uncovering and detecting patterns in multivariate data, hypothesizing and detecting relationships among variables, conducting confirmatory analyses, and building models for predictive and descriptive purposes. It will present predictive modeling in the context of balancing predictive and descriptive accuracies.CoreTime Series Analysis and ForecastingLetter GradeTime Series Analysis is a science as well as the art of making rational predictions based on previous records. It is widely used in various fields in today’s business settings.ElectiveElective 1Letter GradeElective offerings vary
# passage: . In Law courses, students will gain a legal foundation in the concepts of statutory interpretation, judicial decision-making, and legal research before expanding into an interdisciplinary exploration of how law intersects business. At Booth, students will gain a management education that is grounded in the core principles with a multidisciplinary approach to problem solving. You will evaluate problems through the fundamentals underlying business and accounting, economics, psychology, sociology, and statistics.Speaker:Now that you have a better understanding of the program itself, let's transition to talking about the JD/MBA application process, which is a little different from a traditional MBA or JD route. For both the three-year accelerated and four-year option, it is a two-step process
# passage: The program advanced my career by providing systematic learning structure, practical project experience, and inspiring discussion environment. The degree also helped me open doors to new opportunities.
# passage: Please review theHow to Applypage.
# passage: . We've also learned a great deal from each other along the way! [Founder & CEO] and I are really looki
# ng forward to continuing our work together in the Autumn and seeing where our project can go next.
# What Makes a “Good” Problem Statement?
# The exciting field of data science is constantly evolving, and students that
#  enter  the  MS  in  Applied  Data  Science  program  have  a  wide  variety  o
# f interests. Projects that resonate with students can vary by quarter. That sai
# d, there are a few recommendations we can offer to make projects compell
# ing to all cohorts:
# Prepare a rich data set deliverable within two weeks of the project start
# Ensure this is a project of scale ... a team of 3-4 students will spend
#  roughly 40 hours per week over 20 weeks on this project
# passage: Upcoming Events & Deadlines
# passage: Professor’s experience, Curriculum, The University ranking position
# passage: Statistics (PhD)
#
#     [QUESTION]
#     query: Can you provide information about the capstone project project?
#
#     Summarize your answers that are easy to follow. Feel free to use a combination of paragraph and bullet points for your answers
#
#
# === Generated Answer ===
#
#     You are an educational assistant.
#     Your task is to extract information related to Master of Science in Applied Data Science program, such as admission requirement, curriculum, faculties, career outcomes, and etc.
#     Use the following context to answer the question.
#
#     [CONTEXT]
#     passage: .Data Science Capstone ProjectThe required Capstone Project is completed over two quarters and covers research design, implementation, and writing.Full-time students start their capstone project in their third quarter. Part-time students generally begin the capstone project in their fifth quarter.
# passage: . A list of sample electives (subject to change) appear at the bottom of theIn-PersonandOnline Programpages.CapstoneData Science Capstone ProjectLetter GradeThe required Capstone Project is completed over two quarters and covers research design, implementation, and writing.Full-time students start their capstone project in their third quarter. Part-time students generally begin the capstone project in their fifth quarter.SeminarCareer Seminar (Required)Pass/FailThe Career Seminar (Pass/Fail) supports the development of industry professional skills, job and/or internship searches, and other in-demand areas of competency among today’s employers. Students enroll in the Career Seminar each quarter in order to engage in unique content throughout their degree program
# passage: The required Capstone Project is completed over two quarters and covers research design, implementation, and writing.Full-time students start their capstone project in their third quarter. Part-time students generally begin the capstone project in their fifth quarter.
# passage: CONCLUSION: CAPSTONE SHOWCASE
# Project outcomes are virtually presented to the Applied Data Science community
# CAPSTONE II
# Implementation ends
# Project summary and research paper are finalized
# Capstone projects span two academic quarters and conclude with a virtual Showcase. The projects are guided by this outline and more detailed schedule on page 4: Capstone projects span  two acad emic qu arters a nd conclud e wi th a virt ual
#  Showcase. The projects are guided by this outline and more detailed schedule on page 4:
# Capstone I
# Break
# Capstone II
# Capstone
#  Showcase
# Project
#  Timeline
# 02 | 2025
# passage: .CapstoneData Science Capstone ProjectLetter GradeThe required Capstone Project is completed over two quarters and covers research design, implementation, and writing.Full-time students start their capstone project in their third quarter. Part-time students generally begin the capstone project in their fifth quarter.SeminarCareer Seminar (Required)Pass/FailThe Career Seminar (Pass/Fail) supports the development of industry professional skills, job and/or internship searches, and other in-demand areas of competency among today’s employers. Students enroll in the Career Seminar each quarter in order to engage in unique content throughout their degree program. Students with significant full-time work experience may be eligible to waive this course. 0 units, no cost.
# passage: In this course, you’ll complete a research-focused capstone project designed specifically for this joint degree. In a small group, you will collaborate with a real client on a relevant data science project across multiple sectors such as finance, entertainment, automotive, and more.
# passage: Capstone Project (1 required course)
# passage: The requiredCapstone Projectis completed over two quarters and covers research design, implementation, and writing. Full-time students start their Capstone Project in their third quarter. Part-time students generally begin the Capstone Project two quarters before their projected graduation quarter. Students choose among industry- and research-focused projects.
# passage: duties, participation expectations, and project timelines, along with responses to frequently asked questions.  Contact Alison Ossyra, aossyra@uchicago.edu, or Lauren Darga, ldarga@uchicago.edu, with any additional questions or to submit an idea for collaboration.
# For more information ...
# PRIOR TO CAPSTONE I: CALL FOR PROJECT PROPOSALS
# Proposals are reviewed and approved by the MS-ADS program team and instructors
# CAPSTONE I
# Project scope and goals defined with student team
# Data due to student team within two weeks of the start of the respective quarter
# Implementation begins
# BREAK
# Students that start Capstone I in the Spring often choose to complete an internship over the summer
# Students that start Capstone I in the Autumn will have a month break before the Winter quarter
# passage: The Master’s in Applied Data Science program accepts projects year-round for placement during the Spring and Autumn quarter, with the Spring quarter being the largest cohort. All projects must be submitted no later than one month prior to the beginning of the preferred starting quarter based on theUChicago academic calendar.Want more information? Find details and answers to FAQs in this Capstone Sponsorship Guidelines document—click hereto download the PDF.
# passage: MS in Applied Data Science
# The University of Chicago
# Capstone Project Timeline Overview
# Providing your organization’s data is a critical component of the Capstone process,
# and data confidentiality is taken very seriously. By request, students may sign a non-
# disclosure agreement (NDA) provided by your company (MS-ADS staff can offer a
# template, if needed). The NDA would be between students on the project team and
# your organization, as UChicago faculty and staff will not have access to your data.
# DATA SECURITY
# The MS-Applied Data Science program accepts project proposals year-round for placement at the
#  beginning of Spring or Autumn quarters. All proposals must be submitted by mid-February (Spring) or earl
# passage: Capstone Experience
# passage: project outcomes, and data availability are the most enticing to students.
# Submitting a Problem Statement Form
# To proceed, will we need a contract with UChicago MS-ADS?
# No, the MS-ADS program does not require a legally binding agreement. We ask that you review the
#  guidance shared in this document for expectations.
# What about a non-disclosure agreement?
# Students are prepared to sign a non-disclosure agreement (NDA). The NDA would be between
#  students on the project team and your organization, as UChicago faculty and staff will not hav
# e access to your data.
# Is there a cost associated with being a project sponsor?
# While there is no cost owed to the MS-ADS program, we do expect that sponsors will contribute to
# passage: costs that may include mentorship time, hosting the student team for an in-person meeting, and dat
# a sharing and storage/cloud resources. Students may need access to your systems for data, and al
# so may need to have you support credits/costs within cloud platforms (e.g. AWS, Google Cloud, Azure).
# Can I submit more than one proposal?
# Yes! If your team has the capacity to mentor multiple teams at once, you are welcome to submit
#  multiple proposals.
# Before We Get Started ...
# Frequently Asked Questions
# 05 | 2025
# passage: . The application will also ask you to submit your resume, academic transcripts, GMAT or GRE score, essay responses, two letters of recommendation an English language assessment for non-native speaking applicants, and an application fee. We take a holistic approach during our review, meaning we consider every component of your application in our evaluation. We are hoping to see indications of a strong quantitative and technical aptitude through each of these application elements. This allows us to assess your potential for success in our program. The Booth application process goes through three rounds of admission with the first deadline usually occurring around mid-September, the second in early January, and the third and final in early April
# passage: . The goal is to provide marketers with the foundation needed to apply data analytics to real-world challenges they confront daily in their professional lives. Students will learn to identify the web analytic tool right for their specific needs; understand valid and reliable ways to collect, analyze, and visualize data from the web; and utilize data in decision making for their agencies, organizations or clients
# passage: . You do not need to submit two separate applications. Instead, you'll be asked to indicate if you are applying to a joint degree on the Booth application. You would select yes and indicate the MBA and MS in Biomedical Sciences as your program of interest. You'll then be asked to submit all required aspects of a full-time MBA application, which include a completed application, a GMAT or GRE score, education transcripts, a resume, letters of recommendation, and essays. Then you'll be asked to complete a number of supplemental questions about your interest in biomedical sciences. The application will be reviewed by both Booth and Biomedical Sciences admission staff for evaluation
# passage: Get in touch with us to submit your idea for a collaboration or ask us questions about how the partnership process works.
# passage: y September (Autumn) using the MS-Applied Data Science Problem Statement Form. The MS-Applied Data Science program accepts proj
# ect proposals year-round for placement at the beginning of Spring or Autumn quarters. All proposals must be
#  submitted by mid-February (Spring) or early September (Autumn) using the MS-Applied Data Science Problem S
# tatement Form.
# In the event your proposal is submitted late and/or not matched for the upcoming quarter, you will have the option to keep the statement active for the next project start quarter. Before offering the proposal again, we will reach out to confirm that the scope of the project still aligns with your business objectives.
# Submission Process
# passage: Hear from students about their experience inCapstone Projects
# passage: As part of the I-20 or DS-2019 request process, theOffice of International Affairswill conduct a thorough review of financial documentation (e.g. bank statements, letter(s) of support, etc.) to verify that international students have access to the total cost of attendance which includes tuition, student fees, health insurance, books and supplies, and living expenses.
# passage: Request information
# passage: . It gives a rigorous methodological foundation in analytical and software tools to successfully undertake projects in Data Science. Students are exposed to concepts of exploratory analyses for uncovering and detecting patterns in multivariate data, hypothesizing and detecting relationships among variables, conducting confirmatory analyses, and building models for predictive and descriptive purposes. It will present predictive modeling in the context of balancing predictive and descriptive accuracies.CoreTime Series Analysis and ForecastingLetter GradeTime Series Analysis is a science as well as the art of making rational predictions based on previous records. It is widely used in various fields in today’s business settings.ElectiveElective 1Letter GradeElective offerings vary
# passage: . In Law courses, students will gain a legal foundation in the concepts of statutory interpretation, judicial decision-making, and legal research before expanding into an interdisciplinary exploration of how law intersects business. At Booth, students will gain a management education that is grounded in the core principles with a multidisciplinary approach to problem solving. You will evaluate problems through the fundamentals underlying business and accounting, economics, psychology, sociology, and statistics.Speaker:Now that you have a better understanding of the program itself, let's transition to talking about the JD/MBA application process, which is a little different from a traditional MBA or JD route. For both the three-year accelerated and four-year option, it is a two-step process
# passage: The program advanced my career by providing systematic learning structure, practical project experience, and inspiring discussion environment. The degree also helped me open doors to new opportunities.
# passage: Please review theHow to Applypage.
# passage: . We've also learned a great deal from each other along the way! [Founder & CEO] and I are really looki
# ng forward to continuing our work together in the Autumn and seeing where our project can go next.
# What Makes a “Good” Problem Statement?
# The exciting field of data science is constantly evolving, and students that
#  enter  the  MS  in  Applied  Data  Science  program  have  a  wide  variety  o
# f interests. Projects that resonate with students can vary by quarter. That sai
# d, there are a few recommendations we can offer to make projects compell
# ing to all cohorts:
# Prepare a rich data set deliverable within two weeks of the project start
# Ensure this is a project of scale ... a team of 3-4 students will spend
#  roughly 40 hours per week over 20 weeks on this project
# passage: Upcoming Events & Deadlines
# passage: Professor’s experience, Curriculum, The University ranking position
# passage: Statistics (PhD)
#
#     [QUESTION]
#     query: Can you provide information about the capstone project project?
#
#     Summarize your answers that are easy to follow. Feel free to use a combination of paragraph and bullet points for your answers
#     1. The capstone project is a required course that covers research design, implementation, and writing.
#     2. It is completed over two quarters.
#     3. Full-time students start their capstone project in their third quarter, while part-time students generally begin in their fifth quarter.
#     4. Students work in small groups and collaborate with a real client on a relevant data science project across multiple sectors such as finance, entertainment, automotive, and more.
#     5. The project outcomes are virtually presented to the Applied Data Science community in a Showcase.
#     6. Students may sign a non-disclosure agreement (NDA) to protect the data confidentiality of the project.
#     7. The capstone project is a critical component of the Master's in Applied Data Science program.
#     8. The project is guided by an outline and more detailed schedule on page 4 of the Capstone Project Timeline Overview document.
#     9. Proposals for the capstone project are reviewed and approved by the MS-ADS program team and instructors.
#     10. The capstone project is designed to provide students with practical experience in data science and help them apply their knowledge to real-world challenges.
